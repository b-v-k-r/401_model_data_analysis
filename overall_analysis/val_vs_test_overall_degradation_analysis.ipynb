# %% [markdown]
# # Class 1 Degradation Analysis: Val vs Test (Overall)
#
# ## Objective
# Diagnose why Class 1 percentage drops from train to test using decision tree path analysis on the overall dataset.
#
# ## Methodology
# 1. **Overall Decision Tree Analysis**:
#    - Fit a decision tree on combined train+test data to predict `is_test_set`
#    - Extract leaf nodes showing val vs test distribution differences
#    - Calculate Class 1 degradation patterns
# 2. **Comprehensive Output**:
#    - Print overall statistics (class 1 rates, sample sizes)
#    - Print leaf characteristics showing degradation
#    - Identify feature combinations causing degradation
#
# ## Expected Output
# - Overall class 1 rates for train and test
# - Decision tree leaf characteristics
# - Leaf-wise degradation analysis

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.tree import DecisionTreeClassifier, _tree, plot_tree

warnings.filterwarnings('ignore')
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 8)

print("✓ Libraries imported")
# Out:
# ✓ Libraries imported

# %%
# Load and prepare data
df = pd.read_parquet('../actual_data.parquet')
print(f"✓ Data loaded: {df.shape}")

# Clean data
df = df.replace([np.inf, -np.inf], np.nan)
for col in df.select_dtypes(include=['object']).columns:
    df[col] = pd.to_numeric(df[col], errors='ignore')
df = df.fillna(-99999)

# Date splits
june_2024_end = pd.Timestamp('2024-06-30')
july_2024_end = pd.Timestamp('2024-07-31')
august_2024_end = pd.Timestamp('2024-08-31')

val_df = df[(pd.to_datetime(df['CUTOFF_DATE']) > june_2024_end) & 
            (pd.to_datetime(df['CUTOFF_DATE']) <= july_2024_end)].copy()
test_df = df[(pd.to_datetime(df['CUTOFF_DATE']) > july_2024_end) & 
             (pd.to_datetime(df['CUTOFF_DATE']) <= august_2024_end)].copy()

# Load features
features = pd.read_csv('../column_order_401_9_jan.csv')['features'].tolist()

# Extract X and y
X_val = val_df[features].copy()
y_val = val_df['EVER_4DPD_IN_120DAYS'].copy()
X_test = test_df[features].copy()
y_test = test_df['EVER_4DPD_IN_120DAYS'].copy()

print(f"\n✓ Val: {len(X_val):,} samples, Class 1 rate: {y_val.mean():.4f} ({y_val.mean()*100:.2f}%)")
print(f"✓ Test: {len(X_test):,} samples, Class 1 rate: {y_test.mean():.4f} ({y_test.mean()*100:.2f}%)")
print(f"\n⚠️ Class 1 rate change: {((y_test.mean() - y_val.mean()) / y_val.mean() * 100):.2f}%")
# Out:
# ✓ Data loaded: (135592, 362)
#
# ✓ Val: 7,802 samples, Class 1 rate: 0.3013 (30.13%)
# ✓ Test: 4,580 samples, Class 1 rate: 0.2592 (25.92%)
#
# ⚠️ Class 1 rate change: -13.99%

# %% [markdown]
# ## Step 1: Fit Decision Tree and Extract Leaf Characteristics

# %%
# Fit decision tree on overall data
print(f"{'='*120}")
print("FITTING DECISION TREE ON OVERALL DATA")
print(f"{'='*120}\n")

# Combine train and test data
X_combined = pd.concat([X_val, X_test], axis=0, ignore_index=True)
y_combined_class1 = pd.concat([y_val, y_test], axis=0, ignore_index=True)
is_test_combined = np.concatenate([np.zeros(len(X_val)), np.ones(len(X_test))])

print(f"✓ Combined dataset: {len(X_combined):,} samples")
print(f"  - Val: {len(X_val):,} ({len(X_val)/len(X_combined)*100:.2f}%)")
print(f"  - Test: {len(X_test):,} ({len(X_test)/len(X_combined)*100:.2f}%)")

# Fit decision tree
min_samples_leaf = max(50, int(0.005 * len(X_combined)))

tree_model = DecisionTreeClassifier(
    max_depth=8,
    min_samples_leaf=min_samples_leaf,
    criterion='gini',
    random_state=42
)

tree_model.fit(X_combined, is_test_combined)

# Get feature importance
feature_importance = pd.DataFrame({
    'feature': features,
    'importance': tree_model.feature_importances_
}).sort_values('importance', ascending=False)

print(f"\n✓ Decision tree fitted")
print(f"  - Tree depth: {tree_model.get_depth()}")
print(f"  - Number of leaves: {tree_model.get_n_leaves()}")
print(f"  - Min samples per leaf: {min_samples_leaf}")

print(f"\n📊 Top 20 features distinguishing test from train:")
print(feature_importance.head(20).to_string(index=False))

print(f"\n{'='*120}")
# Out:
# ========================================================================================================================
# FITTING DECISION TREE ON OVERALL DATA
# ========================================================================================================================
#
# ✓ Combined dataset: 12,382 samples
#   - Val: 7,802 (63.01%)
#   - Test: 4,580 (36.99%)
#
# ✓ Decision tree fitted
#   - Tree depth: 8
#   - Number of leaves: 56
#   - Min samples per leaf: 61
#
# 📊 Top 20 features distinguishing test from train:
#                                                                        feature  importance
#                                                  TOTAL_OVERDUE_AMOUNT_90TO120D    0.142558
#                                NUM_NOCOUNTERPARTYPAYMENTCOMPLETED_121_TO_150_D    0.118974
#                                            DISTINCT_BANKS_EMI_OVERDUE_90TO120D    0.085744
#                                                               MAX_DPD_90_120_D    0.063324
#                                                 NUM_PAYOUTCREATED_151_TO_180_D    0.051803
#                                                 NUM_PAYOUTCREATED_121_TO_150_D    0.049719
#                                                   AVG_OVERDUE_AMOUNT_120TO150D    0.041869
#                                                  NUM_MAINMONEYCLICK_31_TO_60_D    0.035517
#                              RATIO_OF_MAX_OVERDUE_AMOUNT_LAST_30D_TO_150TO180D    0.028173
#                                         MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS    0.025834
#                               MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED    0.023197
#                                                  NUM_MAINMONEYCLICK_61_TO_90_D    0.019730
#                                                 TOTAL_OVERDUE_AMOUNT_120TO150D    0.019295
#                       RATIO_NUM_DEBIT_TXNS_NUM_CREDIT_TXNS_30TO60D_SMS_BANKING    0.017299
#                                             MAX_CDT_AMT_LAST30D_CC_SMS_BANKING    0.016955
#                       RATIO_AVG_DEBIT_TXNS_AVG_CREDIT_TXNS_LAST30D_SMS_BANKING    0.016615
#                                    MAX_DAYS_PAST_DUE_UNSECURED_270_TO_300_DAYS    0.016055
# RATIO_COUNT_CREDITS_NOT_RECOVERED_60TO90D_COUNT_CREDITS_NOT_RECOVERED_LIFETIME    0.014216
#                          RATIO_CREDIT_GIVEN_90TO120D_CREDIT_RECOVERED_90TO120D    0.013155
#                                    MAX_DAYS_PAST_DUE_UNSECURED_300_TO_330_DAYS    0.012510
#
# ========================================================================================================================

# %%
def format_bounded_conditions(path_conditions, X_leaf_data, feature_names):
    """Convert path conditions to bounded ranges"""
    feature_bounds = {}
    for cond in path_conditions:
        if ' <= ' in cond:
            feat, val = cond.split(' <= ')
            val = float(val)
            if feat not in feature_bounds:
                feature_bounds[feat] = {'lower': None, 'upper': None}
            if feature_bounds[feat]['upper'] is None or val < feature_bounds[feat]['upper']:
                feature_bounds[feat]['upper'] = val
        elif ' > ' in cond:
            feat, val = cond.split(' > ')
            val = float(val)
            if feat not in feature_bounds:
                feature_bounds[feat] = {'lower': None, 'upper': None}
            if feature_bounds[feat]['lower'] is None or val > feature_bounds[feat]['lower']:
                feature_bounds[feat]['lower'] = val
    
    for feat, bounds in feature_bounds.items():
        feat_idx = feature_names.index(feat)
        feat_data = X_leaf_data[:, feat_idx]
        if bounds['lower'] is None:
            bounds['lower'] = feat_data.min()
        if bounds['upper'] is None:
            bounds['upper'] = feat_data.max()
    
    formatted = []
    for feat, bounds in sorted(feature_bounds.items()):
        formatted.append(f"{bounds['lower']:.4f} < {feat} <= {bounds['upper']:.4f}")
    return formatted

def extract_decision_paths(tree, feature_names, X, y_class1, is_test):
    """Extract all decision paths from tree"""
    tree_ = tree.tree_
    feature_name = [feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!" for i in tree_.feature]
    paths = []
    
    def recurse(node, path_conditions):
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            recurse(tree_.children_left[node], path_conditions + [f"{name} <= {threshold:.4f}"])
            recurse(tree_.children_right[node], path_conditions + [f"{name} > {threshold:.4f}"])
        else:
            leaf_idx = tree.apply(X) == node
            n_val = (is_test[leaf_idx] == 0).sum()
            n_test = (is_test[leaf_idx] == 1).sum()
            val_class1_rate = y_class1[leaf_idx][is_test[leaf_idx] == 0].mean() if n_val > 0 else 0
            test_class1_rate = y_class1[leaf_idx][is_test[leaf_idx] == 1].mean() if n_test > 0 else 0
            class1_diff = test_class1_rate - val_class1_rate
            
            paths.append({
                'node_id': node,
                'path': ' AND '.join(format_bounded_conditions(path_conditions, X[leaf_idx], feature_names)) if path_conditions else 'root',
                'n_conditions': len(path_conditions),
                'n_samples': n_val + n_test,
                'n_val': n_val,
                'n_test': n_test,
                'test_purity': n_test / (n_val + n_test) if (n_val + n_test) > 0 else 0,
                'val_class1_rate': val_class1_rate,
                'test_class1_rate': test_class1_rate,
                'class1_diff': class1_diff,
                'class1_diff_pct': (class1_diff / val_class1_rate * 100) if val_class1_rate > 0 else 0,
                'impact_score': class1_diff * (n_val + n_test)
            })
    
    recurse(0, [])
    return pd.DataFrame(paths)

# Extract paths
print(f"\n{'='*120}")
print("EXTRACTING DECISION TREE LEAF CHARACTERISTICS")
print(f"{'='*120}\n")

df_paths = extract_decision_paths(tree_model, features, X_combined.values, y_combined_class1.values, is_test_combined)

# Filter valid leaves
min_samples_per_split = 20
df_paths_valid = df_paths[(df_paths['n_val'] >= min_samples_per_split) & (df_paths['n_test'] >= min_samples_per_split)].copy()

print(f"✓ Total leaves: {len(df_paths)}")
print(f"✓ Valid leaves (min {min_samples_per_split} samples): {len(df_paths_valid)}")

# Add metrics
expected_test_pct = len(X_test) / len(X_combined)
df_paths_valid['test_overrep_%'] = (df_paths_valid['test_purity'] / expected_test_pct - 1) * 100
df_paths_valid['pct_of_val'] = df_paths_valid['n_val'] / len(X_val) * 100
df_paths_valid['pct_of_test'] = df_paths_valid['n_test'] / len(X_test) * 100
df_ranked = df_paths_valid.sort_values('impact_score', ascending=True).reset_index(drop=True)

print(f"\n{'='*120}")
print("TOP 10 LEAVES WITH HIGHEST CLASS 1 SUPPRESSION")
print(f"{'='*120}\n")

for idx, row in df_ranked.head(10).iterrows():
    print(f"\n{'-'*120}")
    print(f"Leaf #{idx + 1} | Impact Score: {row['impact_score']:.2f}")
    print(f"{'-'*120}")
    print(f"\n📍 Decision Path ({row['n_conditions']} conditions):")
    if row['path'] != 'root':
        for i, cond in enumerate(row['path'].split(' AND '), 1):
            print(f"  {i}. {cond}")
    print(f"\n📊 Population:")
    print(f"  • Total: {row['n_samples']:,} ({row['n_samples']/len(X_combined)*100:.2f}%)")
    print(f"  • Val: {row['n_val']:,} ({row['pct_of_val']:.2f}%)")
    print(f"  • Test: {row['n_test']:,} ({row['pct_of_test']:.2f}%)")
    print(f"  • Test purity: {row['test_purity']:.2%}")
    print(f"\n🎯 Class 1 Analysis:")
    print(f"  • Val: {row['val_class1_rate']:.4f} ({row['val_class1_rate']*100:.2f}%)")
    print(f"  • Test: {row['test_class1_rate']:.4f} ({row['test_class1_rate']*100:.2f}%)")
    print(f"  • Change: {row['class1_diff_pct']:.2f}%")

print(f"\n{'='*120}")
# Out:
# ========================================================================================================================
# EXTRACTING DECISION TREE LEAF CHARACTERISTICS
# ========================================================================================================================
#
# ✓ Total leaves: 56
# ✓ Valid leaves (min 20 samples): 35
#
# ========================================================================================================================
# TOP 10 LEAVES WITH HIGHEST CLASS 1 SUPPRESSION
# ========================================================================================================================
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Leaf #1 | Impact Score: -130.76
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (8 conditions):
#   1. -99999.0000 < MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED <= 194.5000
#   2. -99999.0000 < NUM_MAINMONEYCLICK_31_TO_60_D <= 0.5000
#   3. -99999.0000 < NUM_NOCOUNTERPARTYPAYMENTCOMPLETED_121_TO_150_D <= 2.5000
#   4. -99999.0000 < NUM_PAYOUTCREATED_121_TO_150_D <= 25.5000
#   5. -99999.0000 < NUM_PAYOUTCREATED_151_TO_180_D <= 25.5000
#   6. 1.2551 < RATIO_AVG_DEBIT_TXNS_AVG_CREDIT_TXNS_LAST30D_SMS_BANKING <= 87.0009
#   7. -99999.0000 < RATIO_NUM_DEBIT_TXNS_NUM_CREDIT_TXNS_30TO60D_SMS_BANKING <= 2.9205
#   8. -99999.0000 < TOTAL_OVERDUE_AMOUNT_90TO120D <= 189.5000
#
# 📊 Population:
#   • Total: 2,393 (19.33%)
#   • Val: 1,386 (17.76%)
#   • Test: 1,007 (21.99%)
#   • Test purity: 42.08%
#
# 🎯 Class 1 Analysis:
#   • Val: 0.3377 (33.77%)
#   • Test: 0.2830 (28.30%)
#   • Change: -16.18%
#
# ------------------------------------------------------------------------------------------------------------------------
# Leaf #2 | Impact Score: -56.97
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (8 conditions):
#   1. -99999.0000 < MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED <= 194.5000
#   2. -99999.0000 < MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_P10 <= 128.8500
#   3. -99999.0000 < NUM_MAINMONEYCLICK_31_TO_60_D <= 0.5000
#   4. -99999.0000 < NUM_NOCOUNTERPARTYPAYMENTCOMPLETED_121_TO_150_D <= 2.5000
#   5. -99999.0000 < NUM_PAYOUTCREATED_121_TO_150_D <= 25.5000
#   6. -99999.0000 < NUM_PAYOUTCREATED_151_TO_180_D <= 25.5000
#   7. -99999.0000 < RATIO_AVG_DEBIT_TXNS_AVG_CREDIT_TXNS_LAST30D_SMS_BANKING <= 1.2551
#   8. -99999.0000 < TOTAL_OVERDUE_AMOUNT_90TO120D <= 189.5000
#
# 📊 Population:
#   • Total: 2,604 (21.03%)
#   • Val: 1,714 (21.97%)
#   • Test: 890 (19.43%)
#   • Test purity: 34.18%
#
# 🎯 Class 1 Analysis:
#   • Val: 0.2870 (28.70%)
#   • Test: 0.2652 (26.52%)
#   • Change: -7.62%
#
# ------------------------------------------------------------------------------------------------------------------------
# Leaf #3 | Impact Score: -43.52
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (8 conditions):
#   1. -49999.5000 < MAX_DAYS_PAST_DUE_UNSECURED_120_TO_150_DAYS <= 900.0000
#   2. -49999.5000 < MAX_DAYS_PAST_DUE_UNSECURED_300_TO_330_DAYS <= 900.0000
#   3. 194.5000 < MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED <= 45509.0000
#   4. -99999.0000 < NUM_MAINMONEYCLICK_31_TO_60_D <= 0.5000
#   5. -99999.0000 < NUM_NOCOUNTERPARTYPAYMENTCOMPLETED_121_TO_150_D <= 2.5000
#   6. -99999.0000 < NUM_PAYOUTCREATED_121_TO_150_D <= 25.5000
#   7. -99999.0000 < NUM_PAYOUTCREATED_151_TO_180_D <= 25.5000
#   8. -99999.0000 < TOTAL_OVERDUE_AMOUNT_90TO120D <= 189.5000
#
# 📊 Population:
#   • Total: 1,355 (10.94%)
#   • Val: 957 (12.27%)
#   • Test: 398 (8.69%)
#   • Test purity: 29.37%
#
# 🎯 Class 1 Analysis:
#   • Val: 0.2884 (28.84%)
#   • Test: 0.2563 (25.63%)
#   • Change: -11.14%
#
# ------------------------------------------------------------------------------------------------------------------------
# Leaf #4 | Impact Score: -32.22
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (8 conditions):
#   1. -99999.0000 < MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED <= 194.5000
#   2. -99999.0000 < NUM_MAINMONEYCLICK_31_TO_60_D <= 0.5000
#   3. -99999.0000 < NUM_NOCOUNTERPARTYPAYMENTCOMPLETED_121_TO_150_D <= 2.5000
#   4. -99999.0000 < NUM_PAYOUTCREATED_121_TO_150_D <= 25.5000
#   5. -99999.0000 < NUM_PAYOUTCREATED_151_TO_180_D <= 25.5000
#   6. 1.2551 < RATIO_AVG_DEBIT_TXNS_AVG_CREDIT_TXNS_LAST30D_SMS_BANKING <= 70.1430
#   7. 2.9205 < RATIO_NUM_DEBIT_TXNS_NUM_CREDIT_TXNS_30TO60D_SMS_BANKING <= 98.0000
#   8. -99999.0000 < TOTAL_OVERDUE_AMOUNT_90TO120D <= 189.5000
#
# 📊 Population:
#   • Total: 903 (7.29%)
#   • Val: 608 (7.79%)
#   • Test: 295 (6.44%)
#   • Test purity: 32.67%
#
# 🎯 Class 1 Analysis:
#   • Val: 0.3306 (33.06%)
#   • Test: 0.2949 (29.49%)
#   • Change: -10.79%
#
# ------------------------------------------------------------------------------------------------------------------------
# Leaf #5 | Impact Score: -29.62
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (8 conditions):
#   1. -99999.0000 < DISTINCT_BANKS_EMI_OVERDUE_90TO120D <= 0.5000
#   2. -49999.5000 < MAX_DAYS_PAST_DUE_ACTIVE_630_TO_660_DAYS <= 319.0000
#   3. 0.0000 < NUM_MAINMONEYCLICK_61_TO_90_D <= 0.5000
#   4. 6.5000 < NUM_NOCOUNTERPARTYPAYMENTCOMPLETED_121_TO_150_D <= 35.0000
#   5. 0.0000 < NUM_PAYOUTCREATED_121_TO_150_D <= 21.5000
#   6. -99999.0000 < RATIO_CREDIT_GIVEN_LAST30D_CREDIT_RECOVERED_LAST30D <= 1.1064
#   7. -99999.0000 < TOTAL_OVERDUE_AMOUNT_90TO120D <= 189.5000
#
# 📊 Population:
#   • Total: 179 (1.45%)
#   • Val: 108 (1.38%)
#   • Test: 71 (1.55%)
#   • Test purity: 39.66%
#
# 🎯 Class 1 Analysis:
#   • Val: 0.2500 (25.00%)
#   • Test: 0.0845 (8.45%)
#   • Change: -66.20%
#
# ------------------------------------------------------------------------------------------------------------------------
# Leaf #6 | Impact Score: -25.98
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (8 conditions):
#   1. -99999.0000 < DISTINCT_BANKS_EMI_OVERDUE_90TO120D <= 0.5000
#   2. -99999.0000 < MAX_DAYS_PAST_DUE_ACTIVE_630_TO_660_DAYS <= -49999.5000
#   3. 0.0000 < NUM_MAINMONEYCLICK_61_TO_90_D <= 0.5000
#   4. 6.5000 < NUM_NOCOUNTERPARTYPAYMENTCOMPLETED_121_TO_150_D <= 39.0000
#   5. 0.0000 < NUM_PAYOUTCREATED_121_TO_150_D <= 21.5000
#   6. 14.0000 < NUM_SMS_180D_SMS_BANKING <= 2276.0000
#   7. -99999.0000 < TOTAL_OVERDUE_AMOUNT_90TO120D <= 189.5000
#
# 📊 Population:
#   • Total: 289 (2.33%)
#   • Val: 215 (2.76%)
#   • Test: 74 (1.62%)
#   • Test purity: 25.61%
#
# 🎯 Class 1 Analysis:
#   • Val: 0.2791 (27.91%)
#   • Test: 0.1892 (18.92%)
#   • Change: -32.21%
#
# ------------------------------------------------------------------------------------------------------------------------
# Leaf #7 | Impact Score: -20.17
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (8 conditions):
#   1. -99999.0000 < MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED <= 67.0000
#   2. 0.5000 < NUM_MAINMONEYCLICK_31_TO_60_D <= 21.0000
#   3. 0.0000 < NUM_NOCOUNTERPARTYPAYMENTCOMPLETED_121_TO_150_D <= 2.5000
#   4. 0.0000 < NUM_PAYOUTCREATED_121_TO_150_D <= 25.5000
#   5. 0.0000 < NUM_PAYOUTCREATED_151_TO_180_D <= 25.5000
#   6. 0.0229 < RATIO_COUNT_CREDITS_NOT_RECOVERED_60TO90D_COUNT_CREDITS_NOT_RECOVERED_LIFETIME <= 1.0000
#   7. 0.9834 < RATIO_NUM_DEBIT_TXNS_NUM_CREDIT_TXNS_LAST30D_SMS_BANKING <= 86.0000
#   8. -99999.0000 < TOTAL_OVERDUE_AMOUNT_90TO120D <= 189.5000
#
# 📊 Population:
#   • Total: 122 (0.99%)
#   • Val: 37 (0.47%)
#   • Test: 85 (1.86%)
#   • Test purity: 69.67%
#
# 🎯 Class 1 Analysis:
#   • Val: 0.4595 (45.95%)
#   • Test: 0.2941 (29.41%)
#   • Change: -35.99%
#
# ------------------------------------------------------------------------------------------------------------------------
# Leaf #8 | Impact Score: -15.24
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (6 conditions):
#   1. 0.0000 < AVG_OVERDUE_AMOUNT_120TO150D <= 27.5150
#   2. 0.5000 < DISTINCT_BANKS_EMI_OVERDUE_90TO120D <= 2.0000
#   3. 61327.0254 < MAX_AVAILABLE_BALANCE_60TO90D_SMS_BANKING <= 10349347.0000
#   4. 2.5000 < NUM_NOCOUNTERPARTYPAYMENTCOMPLETED_121_TO_150_D <= 30.0000
#   5. -49999.5000 < RATIO_OF_MAX_OVERDUE_AMOUNT_LAST_30D_TO_150TO180D <= 9628.7393
#   6. 0.0000 < TOTAL_OVERDUE_AMOUNT_90TO120D <= 189.5000
#
# 📊 Population:
#   • Total: 62 (0.50%)
#   • Val: 36 (0.46%)
#   • Test: 26 (0.57%)
#   • Test purity: 41.94%
#
# 🎯 Class 1 Analysis:
#   • Val: 0.3611 (36.11%)
#   • Test: 0.1154 (11.54%)
#   • Change: -68.05%
#
# ------------------------------------------------------------------------------------------------------------------------
# Leaf #9 | Impact Score: -13.41
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (8 conditions):
#   1. -49999.5000 < MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS <= 23.0000
#   2. 0.5000 < NUM_MAINMONEYCLICK_31_TO_60_D <= 48.0000
#   3. 0.0000 < NUM_NOCOUNTERPARTYPAYMENTCOMPLETED_121_TO_150_D <= 2.5000
#   4. 0.0000 < NUM_PAYOUTCREATED_121_TO_150_D <= 25.5000
#   5. 0.0000 < NUM_PAYOUTCREATED_151_TO_180_D <= 25.5000
#   6. -99999.0000 < RATIO_COUNT_CREDITS_NOT_RECOVERED_60TO90D_COUNT_CREDITS_NOT_RECOVERED_LIFETIME <= 0.0229
#   7. -99999.0000 < TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_UNSECURED_AND_CLOSED <= 614378.0000
#   8. -99999.0000 < TOTAL_OVERDUE_AMOUNT_90TO120D <= 189.5000
#
# 📊 Population:
#   • Total: 214 (1.73%)
#   • Val: 151 (1.94%)
#   • Test: 63 (1.38%)
#   • Test purity: 29.44%
#
# 🎯 Class 1 Analysis:
#   • Val: 0.3642 (36.42%)
#   • Test: 0.3016 (30.16%)
#   • Change: -17.20%
#
# ------------------------------------------------------------------------------------------------------------------------
# Leaf #10 | Impact Score: -12.75
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (8 conditions):
#   1. -99999.0000 < DISTINCT_BANKS_EMI_OVERDUE_90TO120D <= 0.5000
#   2. -49999.5000 < MAX_DAYS_PAST_DUE_ACTIVE_630_TO_660_DAYS <= 23.0000
#   3. 0.0000 < NUM_MAINMONEYCLICK_61_TO_90_D <= 0.5000
#   4. 6.5000 < NUM_NOCOUNTERPARTYPAYMENTCOMPLETED_121_TO_150_D <= 31.0000
#   5. 0.0000 < NUM_PAYOUTCREATED_121_TO_150_D <= 21.5000
#   6. 1.1064 < RATIO_CREDIT_GIVEN_LAST30D_CREDIT_RECOVERED_LAST30D <= 65.5571
#   7. -99999.0000 < TOTAL_OVERDUE_AMOUNT_90TO120D <= 189.5000
#
# 📊 Population:
#   • Total: 73 (0.59%)
#   • Val: 28 (0.36%)
#   • Test: 45 (0.98%)
#   • Test purity: 61.64%
#
# 🎯 Class 1 Analysis:
#   • Val: 0.2857 (28.57%)
#   • Test: 0.1111 (11.11%)
#   • Change: -61.11%
#
# ========================================================================================================================

# %%
# Summary
print(f"\n{'='*120}")
print("SUMMARY")
print(f"{'='*120}\n")

print(f"📊 OVERALL STATISTICS:")
print(f"  • Train samples: {len(X_val):,}, Class 1: {y_val.mean()*100:.2f}%")
print(f"  • Test samples: {len(X_test):,}, Class 1: {y_test.mean()*100:.2f}%")
print(f"  • Class 1 degradation: {((y_test.mean() - y_val.mean()) / y_val.mean() * 100):.2f}%")

print(f"\n🌳 TREE ANALYSIS:")
print(f"  • Tree depth: {tree_model.get_depth()}, Leaves: {tree_model.get_n_leaves()}")
print(f"  • Valid leaves analyzed: {len(df_paths_valid)}")
print(f"  • Leaves with degradation: {(df_paths_valid['class1_diff'] < 0).sum()}")

print(f"\n📈 KEY FINDINGS:")
print(f"  • Average impact score: {df_paths_valid['impact_score'].mean():.2f}")
print(f"  • Worst degradation: {df_ranked.iloc[0]['class1_diff_pct']:.2f}%")

print(f"\n💡 RECOMMENDATIONS:")
print(f"  1. Focus on top 10 leaves with highest degradation")
print(f"  2. Investigate feature distributions in affected leaves")
print(f"  3. Monitor similar patterns in future data")

print(f"\n✓ Analysis complete!")
print(f"{'='*120}")
# Out:
# ========================================================================================================================
# SUMMARY
# ========================================================================================================================
#
# 📊 OVERALL STATISTICS:
#   • Train samples: 7,802, Class 1: 30.13%
#   • Test samples: 4,580, Class 1: 25.92%
#   • Class 1 degradation: -13.99%
#
# 🌳 TREE ANALYSIS:
#   • Tree depth: 8, Leaves: 56
#   • Valid leaves analyzed: 35
#   • Leaves with degradation: 27
#
# 📈 KEY FINDINGS:
#   • Average impact score: -12.60
#   • Worst degradation: -16.18%
#
# 💡 RECOMMENDATIONS:
#   1. Focus on top 10 leaves with highest degradation
#   2. Investigate feature distributions in affected leaves
#   3. Monitor similar patterns in future data
#
# ✓ Analysis complete!
# ========================================================================================================================
