# %% [markdown]
# # Class 1 Degradation Analysis: Train vs Val (Cluster-wise)
#
# ## Objective
# Diagnose why Class 1 percentage drops from train to val using clustering + decision tree path analysis.
#
# ## Methodology
# 1. **Clustering Phase**:
#    - Perform clustering on training data using top features
#    - Optimize number of clusters using silhouette score
#    - Identify best clustering configuration
# 2. **Cluster-wise Analysis**:
#    - For each cluster, fit a decision tree to predict `is_val_set`
#    - Extract leaf nodes showing train vs val distribution differences
#    - Calculate Class 1 degradation within each cluster
# 3. **Comprehensive Output**:
#    - Print cluster characteristics (size, features, class 1 rates)
#    - Print leaf characteristics within each cluster
#    - Identify cluster-specific feature combinations causing degradation
#
# ## Expected Output
# - Optimal cluster configuration based on silhouette score
# - Cluster characteristics (population, feature distributions, class 1 rates)
# - Within-cluster decision paths showing degradation
# - Cluster-wise and leaf-wise degradation analysis

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import warnings
from sklearn.tree import DecisionTreeClassifier, _tree, plot_tree
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
import optuna

warnings.filterwarnings('ignore')
optuna.logging.set_verbosity(optuna.logging.WARNING)
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 8)

print("✓ Libraries imported")
# Out:
# ✓ Libraries imported

# %%
# Load and prepare data
df = pd.read_parquet('../actual_data.parquet')
print(f"✓ Data loaded: {df.shape}")

# Clean data
df = df.replace([np.inf, -np.inf], np.nan)
for col in df.select_dtypes(include=['object']).columns:
    df[col] = pd.to_numeric(df[col], errors='ignore')
df = df.fillna(-99999)

# Date splits
june_2024_end = pd.Timestamp('2024-06-30')
july_2024_end = pd.Timestamp('2024-07-31')
august_2024_end = pd.Timestamp('2024-08-31')

train_df = df[pd.to_datetime(df['CUTOFF_DATE']) <= june_2024_end].query("EVER_4DPD_IN_120DAYS != -99999").copy()
val_df = df[(pd.to_datetime(df['CUTOFF_DATE']) > june_2024_end) & 
            (pd.to_datetime(df['CUTOFF_DATE']) <= july_2024_end)].copy()

# Load features
features = pd.read_csv('../column_order_401_9_jan.csv')['features'].tolist()

# Extract X and y
X_train = train_df[features].clip(lower=-1e20, upper=1e20).copy()
y_train = train_df['EVER_4DPD_IN_120DAYS'].copy()

X_val = val_df[features].copy()
y_val = val_df['EVER_4DPD_IN_120DAYS'].copy()

print(f"\n✓ Train: {len(X_train):,} samples, Class 1 rate: {y_train.mean():.4f} ({y_train.mean()*100:.2f}%)")
print(f"✓ Val: {len(X_val):,} samples, Class 1 rate: {y_val.mean():.4f} ({y_val.mean()*100:.2f}%)")
print(f"\n⚠️ Class 1 rate change: {((y_val.mean() - y_train.mean()) / y_train.mean() * 100):.2f}%)")
# Out:
# ✓ Data loaded: (135592, 362)
#
# ✓ Train: 123,208 samples, Class 1 rate: 0.3119 (31.19%)
# ✓ Val: 7,802 samples, Class 1 rate: 0.3013 (30.13%)
#
# ⚠️ Class 1 rate change: -3.37%)

# %% [markdown]
# ## Step 1: Find Optimal Clustering using Optuna (Best Silhouette Score)

# %%
# Select top features for clustering (use top features from preliminary tree)
# We'll use a preliminary tree to identify important features
preliminary_tree = DecisionTreeClassifier(max_depth=8, min_samples_leaf=1000, random_state=42)
preliminary_tree.fit(pd.concat([X_train, X_val]), np.concatenate([np.zeros(len(X_train)), np.ones(len(X_val))]))

feature_importance_prelim = pd.DataFrame({
    'feature': features,
    'importance': preliminary_tree.feature_importances_
}).sort_values('importance', ascending=False)

print(f"✓ Preliminary feature importance calculated")
print(f"\n📊 Top 20 features from preliminary tree:")
print(feature_importance_prelim.head(20).to_string(index=False))

# Prepare data for clustering (use only train data)
print(f"\n{'='*120}")
print("OPTUNA HYPERPARAMETER OPTIMIZATION FOR CLUSTERING")
print(f"{'='*120}\n")

# Precalculate scaled data for maximum features to avoid repeated scaling
max_features = 50
clustering_features_max = feature_importance_prelim.head(max_features)['feature'].tolist()
X_train_cluster_max = X_train[clustering_features_max].copy()
scaler_global = StandardScaler()
X_train_scaled_max = scaler_global.fit_transform(X_train_cluster_max)

# Determine if subsampling is needed for silhouette calculation
use_subsample = len(X_train_scaled_max) > 10000
if use_subsample:
    subsample_size = 10000
    sample_idx = np.random.choice(len(X_train_scaled_max), subsample_size, replace=False)
    print(f"⚡ Using subsampling for silhouette score (dataset size: {len(X_train_scaled_max):,} > 10,000)")
    print(f"   Silhouette calculated on {subsample_size:,} samples per trial\n")
else:
    print(f"✓ Using full dataset for silhouette score (dataset size: {len(X_train_scaled_max):,})\n")

def objective(trial):
    """
    Optuna objective function to maximize silhouette score.
    
    Hyperparameters to tune:
    - n_clusters: number of clusters (2-10)
    - n_features: number of top features to use (10-50)
    - init: initialization method ('k-means++' only for speed)
    - n_init: number of times k-means runs with different seeds (5-10)
    - max_iter: maximum iterations (100-300)
    """
    
    # Suggest hyperparameters
    n_clusters = trial.suggest_int('n_clusters', 2, 10)
    n_features = trial.suggest_int('n_features', 10, 50)
    init_method = trial.suggest_categorical('init', ['k-means++'])
    n_init = trial.suggest_int('n_init', 5, 10)
    max_iter = trial.suggest_int('max_iter', 100, 300)
    
    # Slice precomputed scaled data to n_features
    X_scaled = X_train_scaled_max[:, :n_features]
    
    # Fit KMeans with suggested hyperparameters
    kmeans = KMeans(
        n_clusters=n_clusters,
        init=init_method,
        n_init=n_init,
        max_iter=max_iter,
        random_state=42
    )
    
    labels = kmeans.fit_predict(X_scaled)
    
    # Calculate silhouette score (subsample if dataset is large)
    if use_subsample:
        score = silhouette_score(X_scaled[sample_idx], labels[sample_idx])
    else:
        score = silhouette_score(X_scaled, labels)
    
    return score

# Create Optuna study with pruning for faster convergence
print("🔍 Starting Optuna optimization...")
print("   This will val different combinations of:")
print("   - Number of clusters (2-10)")
print("   - Number of features (10-50)")
print("   - Initialization method (k-means++)")
print("   - Number of initializations (5-10)")
print("   - Maximum iterations (100-300)")
print("\n   Running 50 trials with median pruning to find optimal configuration...\n")

study = optuna.create_study(
    direction='maximize',
    study_name='clustering_optimization',
    pruner=optuna.pruners.MedianPruner(n_startup_trials=10, n_warmup_steps=5)
)
study.optimize(objective, n_trials=50, show_progress_bar=True)

# Get best parameters
best_params = study.best_params
best_silhouette_score = study.best_value

print(f"\n{'='*120}")
print("OPTUNA OPTIMIZATION RESULTS")
print(f"{'='*120}")
print(f"\n🏆 BEST HYPERPARAMETERS:")
print(f"   • Number of clusters: {best_params['n_clusters']}")
print(f"   • Number of features: {best_params['n_features']}")
print(f"   • Initialization method: {best_params['init']}")
print(f"   • Number of initializations: {best_params['n_init']}")
print(f"   • Maximum iterations: {best_params['max_iter']}")
print(f"\n🎯 BEST SILHOUETTE SCORE: {best_silhouette_score:.4f}")
print(f"{'='*120}")

# Extract optimal parameters
optimal_n_clusters = best_params['n_clusters']
optimal_n_features = best_params['n_features']
optimal_init = best_params['init']
optimal_n_init = best_params['n_init']
optimal_max_iter = best_params['max_iter']

# Visualize optimization history
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Plot 1: Optimization history
ax1 = axes[0]
trials_df = study.trials_dataframe()
ax1.plot(trials_df['number'], trials_df['value'], marker='o', linestyle='-', alpha=0.6, markersize=4)
ax1.axhline(y=best_silhouette_score, color='red', linestyle='--', linewidth=2, label=f'Best: {best_silhouette_score:.4f}')
ax1.set_xlabel('Trial Number', fontsize=11, fontweight='bold')
ax1.set_ylabel('Silhouette Score', fontsize=11, fontweight='bold')
ax1.set_title('Optuna Optimization History', fontsize=13, fontweight='bold', pad=10)
ax1.legend(fontsize=10)
ax1.grid(True, alpha=0.3)

# Plot 2: Parameter importance
ax2 = axes[1]
importance = optuna.importance.get_param_importances(study)
params = list(importance.keys())
values = list(importance.values())
colors = plt.cm.viridis(np.linspace(0.3, 0.9, len(params)))
ax2.barh(params, values, color=colors, alpha=0.8)
ax2.set_xlabel('Importance', fontsize=11, fontweight='bold')
ax2.set_title('Hyperparameter Importance', fontsize=13, fontweight='bold', pad=10)
ax2.grid(axis='x', alpha=0.3)

plt.tight_layout()
plt.show()

print(f"\n📊 Hyperparameter Importance:")
for param, importance_val in importance.items():
    print(f"   • {param}: {importance_val:.4f}")

# Visualize silhouette score vs number of clusters
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
cluster_scores = trials_df.groupby('params_n_clusters')['value'].agg(['mean', 'max', 'std'])
x = cluster_scores.index
ax.plot(x, cluster_scores['mean'], marker='o', linewidth=2, markersize=8, label='Mean Silhouette', color='steelblue')
ax.fill_between(x, 
                 cluster_scores['mean'] - cluster_scores['std'], 
                 cluster_scores['mean'] + cluster_scores['std'], 
                 alpha=0.3, color='steelblue', label='±1 Std Dev')
ax.scatter(x, cluster_scores['max'], marker='*', s=200, color='red', label='Max Silhouette', zorder=5)
ax.axvline(x=optimal_n_clusters, color='green', linestyle='--', linewidth=2, alpha=0.7, 
           label=f'Optimal: {optimal_n_clusters} clusters')
ax.set_xlabel('Number of Clusters', fontsize=12, fontweight='bold')
ax.set_ylabel('Silhouette Score', fontsize=12, fontweight='bold')
ax.set_title('Silhouette Score vs Number of Clusters (Across All Trials)', fontsize=14, fontweight='bold', pad=15)
ax.grid(True, alpha=0.3)
ax.legend(fontsize=10)
plt.tight_layout()
plt.show()

# Fit final clustering with optimal hyperparameters
print(f"\n{'='*120}")
print("FITTING FINAL CLUSTERING MODEL")
print(f"{'='*120}")

clustering_features = feature_importance_prelim.head(optimal_n_features)['feature'].tolist()

print(f"\n✓ Using top {optimal_n_features} features for clustering:")
for i, feat in enumerate(clustering_features[:10], 1):
    print(f"   {i}. {feat}")
if optimal_n_features > 10:
    print(f"   ... and {optimal_n_features - 10} more features")

X_train_cluster = X_train[clustering_features].copy()

# Standardize features for clustering
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_cluster)

# Fit final clustering with optimal parameters
kmeans_final = KMeans(
    n_clusters=optimal_n_clusters,
    init=optimal_init,
    n_init=optimal_n_init,
    max_iter=optimal_max_iter,
    random_state=42
)
train_clusters = kmeans_final.fit_predict(X_train_scaled)

# Assign clusters to train data
X_train_with_cluster = X_train.copy()
X_train_with_cluster['cluster'] = train_clusters
y_train_with_cluster = y_train.copy()

# For val data, assign to nearest cluster
X_val_scaled = scaler.transform(X_val[clustering_features])
val_clusters = kmeans_final.predict(X_val_scaled)

X_val_with_cluster = X_val.copy()
X_val_with_cluster['cluster'] = val_clusters
y_val_with_cluster = y_val.copy()

print(f"\n✓ Clustering complete with optimal parameters")
print(f"   • Train samples clustered: {len(train_clusters):,}")
print(f"   • val samples clustered: {len(val_clusters):,}")
print(f"   • Achieved silhouette score: {best_silhouette_score:.4f}")

# Display cluster distribution
print(f"\n📊 Cluster Distribution:")
train_cluster_counts = pd.Series(train_clusters).value_counts().sort_index()
val_cluster_counts = pd.Series(val_clusters).value_counts().sort_index()
for cluster_id in range(optimal_n_clusters):
    train_count = train_cluster_counts.get(cluster_id, 0)
    val_count = val_cluster_counts.get(cluster_id, 0)
    print(f"   Cluster {cluster_id}: Train={train_count:,} ({train_count/len(train_clusters)*100:.1f}%), "
          f"val={val_count:,} ({val_count/len(val_clusters)*100:.1f}%)")

print(f"\n{'='*120}")
# Out:
# ✓ Preliminary feature importance calculated
#
# 📊 Top 20 features from preliminary tree:
#                                                           feature  importance
#                            MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS    0.212932
#                                                       BUREAUSCORE    0.194544
#                                    NUM_MAINMONEYCLICK_91_TO_120_D    0.117421
#                                      NUM_PAYOUTCREATED_31_TO_60_D    0.063269
#                          MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE    0.060703
#                                    NUM_MAINBILLSCLICK_91_TO_120_D    0.059783
#                  MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED    0.056049
#                                     NUM_MAINMONEYCLICK_61_TO_90_D    0.056043
#                                             COUNT_0_DPD_120_150_D    0.052129
#                                                 MAX_DPD_120_150_D    0.027760
# TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_UNSECURED_AND_CLOSED    0.024832
#                  MAX_DAYS_PAST_DUE_ACTIVE_UNSECURED_60_TO_90_DAYS    0.018183
#                                             COUNT_0_DPD_150_180_D    0.015099
#                                        MIN_CURRENT_BALANCE_ACTIVE    0.008410
#        RATIO_OF_DISTINCT_BANKS_LOAN_REPAYMENT_LAST_30D_TO_30TO60D    0.007043
#                         NUM_CUSTOMERKHATAONGOTCLICKED_91_TO_120_D    0.005109
#                                     NUM_MAINMONEYCLICK_31_TO_60_D    0.004448
#                                               AVG_CURRENT_BALANCE    0.003661
#                                               AVG_AMOUNT_PAST_DUE    0.003400
#              AVG_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_UNSECURED    0.003016
#
# ========================================================================================================================
# OPTUNA HYPERPARAMETER OPTIMIZATION FOR CLUSTERING
# ========================================================================================================================
#
# ⚡ Using subsampling for silhouette score (dataset size: 123,208 > 10,000)
#    Silhouette calculated on 10,000 samples per trial
#
# 🔍 Starting Optuna optimization...
#    This will val different combinations of:
#    - Number of clusters (2-10)
#    - Number of features (10-50)
#    - Initialization method (k-means++)
#    - Number of initializations (5-10)
#    - Maximum iterations (100-300)
#
#    Running 50 trials with median pruning to find optimal configuration...
#   0%|          | 0/50 [00:00<?, ?it/s]
# ========================================================================================================================
# OPTUNA OPTIMIZATION RESULTS
# ========================================================================================================================
#
# 🏆 BEST HYPERPARAMETERS:
#    • Number of clusters: 10
#    • Number of features: 11
#    • Initialization method: k-means++
#    • Number of initializations: 6
#    • Maximum iterations: 142
#
# 🎯 BEST SILHOUETTE SCORE: 0.7128
# ========================================================================================================================
# 📊 Hyperparameter Importance:
#    • n_features: 0.9806
#    • n_clusters: 0.0117
#    • max_iter: 0.0053
#    • n_init: 0.0024
#    • init: 0.0000
# ========================================================================================================================
# FITTING FINAL CLUSTERING MODEL
# ========================================================================================================================
#
# ✓ Using top 11 features for clustering:
#    1. MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS
#    2. BUREAUSCORE
#    3. NUM_MAINMONEYCLICK_91_TO_120_D
#    4. NUM_PAYOUTCREATED_31_TO_60_D
#    5. MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE
#    6. NUM_MAINBILLSCLICK_91_TO_120_D
#    7. MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED
#    8. NUM_MAINMONEYCLICK_61_TO_90_D
#    9. COUNT_0_DPD_120_150_D
#    10. MAX_DPD_120_150_D
#    ... and 1 more features
#
# ✓ Clustering complete with optimal parameters
#    • Train samples clustered: 123,208
#    • val samples clustered: 7,802
#    • Achieved silhouette score: 0.7128
#
# 📊 Cluster Distribution:
#    Cluster 0: Train=17,647 (14.3%), val=2,412 (30.9%)
#    Cluster 1: Train=9,571 (7.8%), val=486 (6.2%)
#    Cluster 2: Train=37,461 (30.4%), val=1,274 (16.3%)
#    Cluster 3: Train=19,962 (16.2%), val=2,316 (29.7%)
#    Cluster 4: Train=14,129 (11.5%), val=334 (4.3%)
#    Cluster 5: Train=9,678 (7.9%), val=130 (1.7%)
#    Cluster 6: Train=2 (0.0%), val=0 (0.0%)
#    Cluster 7: Train=818 (0.7%), val=63 (0.8%)
#    Cluster 8: Train=13,939 (11.3%), val=787 (10.1%)
#    Cluster 9: Train=1 (0.0%), val=0 (0.0%)
#
# ========================================================================================================================

# %% [markdown]
# ## Step 2: Cluster Characteristics Analysis

# %%
# Analyze cluster characteristics
print(f"{'='*120}")
print("CLUSTER CHARACTERISTICS ANALYSIS")
print(f"{'='*120}\n")

cluster_stats = []

for cluster_id in range(optimal_n_clusters):
    # Get cluster data
    train_cluster_mask = X_train_with_cluster['cluster'] == cluster_id
    val_cluster_mask = X_val_with_cluster['cluster'] == cluster_id
    
    n_train_cluster = train_cluster_mask.sum()
    n_val_cluster = val_cluster_mask.sum()
    
    # Class 1 rates
    train_class1_rate = y_train_with_cluster[train_cluster_mask].mean() if n_train_cluster > 0 else 0
    val_class1_rate = y_val_with_cluster[val_cluster_mask].mean() if n_val_cluster > 0 else 0
    
    class1_diff = val_class1_rate - train_class1_rate
    class1_diff_pct = (class1_diff / train_class1_rate * 100) if train_class1_rate > 0 else 0
    
    # Cluster centroid characteristics (top 5 features)
    centroid = kmeans_final.cluster_centers_[cluster_id]
    centroid_df = pd.DataFrame({
        'feature': clustering_features,
        'value': scaler.inverse_transform([centroid])[0]
    }).sort_values('value', ascending=False)
    
    print(f"{'='*120}")
    print(f"CLUSTER {cluster_id}")
    print(f"{'='*120}")
    
    print(f"\n📊 CLUSTER POPULATION:")
    print(f"  • Train samples: {n_train_cluster:,} ({n_train_cluster/len(X_train)*100:.2f}% of train)")
    print(f"  • val samples: {n_val_cluster:,} ({n_val_cluster/len(X_val)*100:.2f}% of val)")
    print(f"  • Total samples: {n_train_cluster + n_val_cluster:,}")
    
    print(f"\n🎯 CLUSTER CLASS 1 RATES:")
    print(f"  • Train Class 1 rate: {train_class1_rate:.4f} ({train_class1_rate*100:.2f}%)")
    print(f"  • val Class 1 rate: {val_class1_rate:.4f} ({val_class1_rate*100:.2f}%)")
    print(f"  • Absolute difference: {class1_diff:.4f}")
    print(f"  • Relative change: {class1_diff_pct:.2f}%")
    
    if class1_diff < 0:
        print(f"  • ⚠️  Class 1 DECREASED by {abs(class1_diff_pct):.2f}%")
    else:
        print(f"  • ✓ Class 1 INCREASED by {class1_diff_pct:.2f}%")
    
    print(f"\n📈 TOP 10 CLUSTER CENTROID FEATURES (Highest Values):")
    for idx, row in centroid_df.head(10).iterrows():
        print(f"  • {row['feature']}: {row['value']:.4f}")
    
    print(f"\n📉 BOTTOM 10 CLUSTER CENTROID FEATURES (Lowest Values):")
    for idx, row in centroid_df.tail(10).iterrows():
        print(f"  • {row['feature']}: {row['value']:.4f}")
    
    cluster_stats.append({
        'cluster_id': cluster_id,
        'n_train': n_train_cluster,
        'n_val': n_val_cluster,
        'train_class1_rate': train_class1_rate,
        'val_class1_rate': val_class1_rate,
        'class1_diff': class1_diff,
        'class1_diff_pct': class1_diff_pct
    })
    
    print(f"\n")

cluster_stats_df = pd.DataFrame(cluster_stats)

print(f"{'='*120}")
print("CLUSTER SUMMARY TABLE")
print(f"{'='*120}")
print(cluster_stats_df.to_string(index=False))
print(f"{'='*120}\n")

# Visualize cluster characteristics
fig, axes = plt.subplots(2, 2, figsize=(18, 12))

# Plot 1: Sample distribution
ax1 = axes[0, 0]
x = np.arange(len(cluster_stats_df))
width = 0.35
ax1.bar(x - width/2, cluster_stats_df['n_train'], width, label='Train', alpha=0.8, color='#2E86AB')
ax1.bar(x + width/2, cluster_stats_df['n_val'], width, label='val', alpha=0.8, color='#A23B72')
ax1.set_xlabel('Cluster ID', fontsize=11, fontweight='bold')
ax1.set_ylabel('Sample Count', fontsize=11, fontweight='bold')
ax1.set_title('Sample Distribution by Cluster', fontsize=13, fontweight='bold', pad=10)
ax1.set_xticks(x)
ax1.set_xticklabels([f"C{i}" for i in range(optimal_n_clusters)])
ax1.legend(fontsize=9)
ax1.grid(axis='y', alpha=0.3)

# Plot 2: Class 1 rates
ax2 = axes[0, 1]
ax2.bar(x - width/2, cluster_stats_df['train_class1_rate'], width, label='Train', alpha=0.8, color='#2E86AB')
ax2.bar(x + width/2, cluster_stats_df['val_class1_rate'], width, label='val', alpha=0.8, color='#A23B72')
ax2.axhline(y=y_train.mean(), color='#2E86AB', linestyle='--', linewidth=1.5, alpha=0.6, label='Overall Train')
ax2.axhline(y=y_val.mean(), color='#A23B72', linestyle='--', linewidth=1.5, alpha=0.6, label='Overall val')
ax2.set_xlabel('Cluster ID', fontsize=11, fontweight='bold')
ax2.set_ylabel('Class 1 Rate', fontsize=11, fontweight='bold')
ax2.set_title('Class 1 Rate by Cluster', fontsize=13, fontweight='bold', pad=10)
ax2.set_xticks(x)
ax2.set_xticklabels([f"C{i}" for i in range(optimal_n_clusters)])
ax2.legend(fontsize=9)
ax2.grid(axis='y', alpha=0.3)

# Plot 3: Class 1 difference
ax3 = axes[1, 0]
colors = ['#D32F2F' if val < 0 else '#388E3C' for val in cluster_stats_df['class1_diff']]
ax3.bar(x, cluster_stats_df['class1_diff'], color=colors, alpha=0.7)
ax3.axhline(y=0, color='black', linestyle='-', linewidth=2)
ax3.set_xlabel('Cluster ID', fontsize=11, fontweight='bold')
ax3.set_ylabel('Class 1 Difference (val - Train)', fontsize=11, fontweight='bold')
ax3.set_title('Class 1 Degradation by Cluster\n(Negative = Suppression)', fontsize=13, fontweight='bold', pad=10)
ax3.set_xticks(x)
ax3.set_xticklabels([f"C{i}" for i in range(optimal_n_clusters)])
ax3.grid(axis='y', alpha=0.3)

# Plot 4: Relative change %
ax4 = axes[1, 1]
colors_pct = ['#D32F2F' if val < 0 else '#388E3C' for val in cluster_stats_df['class1_diff_pct']]
ax4.bar(x, cluster_stats_df['class1_diff_pct'], color=colors_pct, alpha=0.7)
ax4.axhline(y=0, color='black', linestyle='-', linewidth=2)
ax4.set_xlabel('Cluster ID', fontsize=11, fontweight='bold')
ax4.set_ylabel('Class 1 Relative Change (%)', fontsize=11, fontweight='bold')
ax4.set_title('Class 1 Relative Degradation by Cluster', fontsize=13, fontweight='bold', pad=10)
ax4.set_xticks(x)
ax4.set_xticklabels([f"C{i}" for i in range(optimal_n_clusters)])
ax4.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

print("✓ Cluster characteristics analysis complete")
# Out:
# ========================================================================================================================
# CLUSTER CHARACTERISTICS ANALYSIS
# ========================================================================================================================
#
# ========================================================================================================================
# CLUSTER 0
# ========================================================================================================================
#
# 📊 CLUSTER POPULATION:
#   • Train samples: 17,647 (14.32% of train)
#   • val samples: 2,412 (30.92% of val)
#   • Total samples: 20,059
#
# 🎯 CLUSTER CLASS 1 RATES:
#   • Train Class 1 rate: 0.3146 (31.46%)
#   • val Class 1 rate: 0.2964 (29.64%)
#   • Absolute difference: -0.0182
#   • Relative change: -5.78%
#   • ⚠️  Class 1 DECREASED by 5.78%
#
# 📈 TOP 10 CLUSTER CENTROID FEATURES (Highest Values):
#   • TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_UNSECURED_AND_CLOSED: 269500.6296
#   • MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE: 5954.3099
#   • BUREAUSCORE: 652.2364
#   • NUM_MAINMONEYCLICK_61_TO_90_D: 3.0172
#   • NUM_MAINMONEYCLICK_91_TO_120_D: 2.3661
#   • NUM_PAYOUTCREATED_31_TO_60_D: 1.2805
#   • MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS: 0.9134
#   • NUM_MAINBILLSCLICK_91_TO_120_D: 0.8920
#   • MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED: -9083.5418
#   • COUNT_0_DPD_120_150_D: -89538.4031
#
# 📉 BOTTOM 10 CLUSTER CENTROID FEATURES (Lowest Values):
#   • MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE: 5954.3099
#   • BUREAUSCORE: 652.2364
#   • NUM_MAINMONEYCLICK_61_TO_90_D: 3.0172
#   • NUM_MAINMONEYCLICK_91_TO_120_D: 2.3661
#   • NUM_PAYOUTCREATED_31_TO_60_D: 1.2805
#   • MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS: 0.9134
#   • NUM_MAINBILLSCLICK_91_TO_120_D: 0.8920
#   • MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED: -9083.5418
#   • COUNT_0_DPD_120_150_D: -89538.4031
#   • MAX_DPD_120_150_D: -99999.0000
#
#
# ========================================================================================================================
# CLUSTER 1
# ========================================================================================================================
#
# 📊 CLUSTER POPULATION:
#   • Train samples: 9,571 (7.77% of train)
#   • val samples: 486 (6.23% of val)
#   • Total samples: 10,057
#
# 🎯 CLUSTER CLASS 1 RATES:
#   • Train Class 1 rate: 0.3847 (38.47%)
#   • val Class 1 rate: 0.3333 (33.33%)
#   • Absolute difference: -0.0514
#   • Relative change: -13.35%
#   • ⚠️  Class 1 DECREASED by 13.35%
#
# 📈 TOP 10 CLUSTER CENTROID FEATURES (Highest Values):
#   • TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_UNSECURED_AND_CLOSED: 82836.7902
#   • BUREAUSCORE: -19396.6535
#   • MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE: -20996.9985
#   • MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED: -41499.3305
#   • MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS: -84316.0247
#   • COUNT_0_DPD_120_150_D: -99079.5214
#   • MAX_DPD_120_150_D: -99727.3423
#   • NUM_MAINMONEYCLICK_91_TO_120_D: -99999.0000
#   • NUM_MAINMONEYCLICK_61_TO_90_D: -99999.0000
#   • NUM_MAINBILLSCLICK_91_TO_120_D: -99999.0000
#
# 📉 BOTTOM 10 CLUSTER CENTROID FEATURES (Lowest Values):
#   • BUREAUSCORE: -19396.6535
#   • MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE: -20996.9985
#   • MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED: -41499.3305
#   • MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS: -84316.0247
#   • COUNT_0_DPD_120_150_D: -99079.5214
#   • MAX_DPD_120_150_D: -99727.3423
#   • NUM_MAINMONEYCLICK_91_TO_120_D: -99999.0000
#   • NUM_MAINMONEYCLICK_61_TO_90_D: -99999.0000
#   • NUM_MAINBILLSCLICK_91_TO_120_D: -99999.0000
#   • NUM_PAYOUTCREATED_31_TO_60_D: -99999.0000
#
#
# ========================================================================================================================
# CLUSTER 2
# ========================================================================================================================
#
# 📊 CLUSTER POPULATION:
#   • Train samples: 37,461 (30.40% of train)
#   • val samples: 1,274 (16.33% of val)
#   • Total samples: 38,735
#
# 🎯 CLUSTER CLASS 1 RATES:
#   • Train Class 1 rate: 0.3042 (30.42%)
#   • val Class 1 rate: 0.3289 (32.89%)
#   • Absolute difference: 0.0247
#   • Relative change: 8.12%
#   • ✓ Class 1 INCREASED by 8.12%
#
# 📈 TOP 10 CLUSTER CENTROID FEATURES (Highest Values):
#   • TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_UNSECURED_AND_CLOSED: 157635.1314
#   • MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE: 15946.5026
#   • BUREAUSCORE: 770.5316
#   • MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED: 585.7774
#   • NUM_MAINMONEYCLICK_61_TO_90_D: 1.8573
#   • NUM_MAINMONEYCLICK_91_TO_120_D: 1.5767
#   • NUM_PAYOUTCREATED_31_TO_60_D: 0.7426
#   • NUM_MAINBILLSCLICK_91_TO_120_D: 0.6521
#   • COUNT_0_DPD_120_150_D: -99999.0000
#   • MAX_DPD_120_150_D: -99999.0000
#
# 📉 BOTTOM 10 CLUSTER CENTROID FEATURES (Lowest Values):
#   • MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE: 15946.5026
#   • BUREAUSCORE: 770.5316
#   • MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED: 585.7774
#   • NUM_MAINMONEYCLICK_61_TO_90_D: 1.8573
#   • NUM_MAINMONEYCLICK_91_TO_120_D: 1.5767
#   • NUM_PAYOUTCREATED_31_TO_60_D: 0.7426
#   • NUM_MAINBILLSCLICK_91_TO_120_D: 0.6521
#   • COUNT_0_DPD_120_150_D: -99999.0000
#   • MAX_DPD_120_150_D: -99999.0000
#   • MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS: -99999.0000
#
#
# ========================================================================================================================
# CLUSTER 3
# ========================================================================================================================
#
# 📊 CLUSTER POPULATION:
#   • Train samples: 19,962 (16.20% of train)
#   • val samples: 2,316 (29.68% of val)
#   • Total samples: 22,278
#
# 🎯 CLUSTER CLASS 1 RATES:
#   • Train Class 1 rate: 0.2909 (29.09%)
#   • val Class 1 rate: 0.2673 (26.73%)
#   • Absolute difference: -0.0236
#   • Relative change: -8.12%
#   • ⚠️  Class 1 DECREASED by 8.12%
#
# 📈 TOP 10 CLUSTER CENTROID FEATURES (Highest Values):
#   • TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_UNSECURED_AND_CLOSED: 248818.8144
#   • MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE: 8357.1300
#   • BUREAUSCORE: 739.3142
#   • COUNT_0_DPD_120_150_D: 19.7097
#   • NUM_MAINMONEYCLICK_91_TO_120_D: 13.1964
#   • NUM_MAINMONEYCLICK_61_TO_90_D: 11.8945
#   • NUM_PAYOUTCREATED_31_TO_60_D: 8.5351
#   • NUM_MAINBILLSCLICK_91_TO_120_D: 2.0673
#   • MAX_DPD_120_150_D: 1.7883
#   • MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED: -6879.4091
#
# 📉 BOTTOM 10 CLUSTER CENTROID FEATURES (Lowest Values):
#   • MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE: 8357.1300
#   • BUREAUSCORE: 739.3142
#   • COUNT_0_DPD_120_150_D: 19.7097
#   • NUM_MAINMONEYCLICK_91_TO_120_D: 13.1964
#   • NUM_MAINMONEYCLICK_61_TO_90_D: 11.8945
#   • NUM_PAYOUTCREATED_31_TO_60_D: 8.5351
#   • NUM_MAINBILLSCLICK_91_TO_120_D: 2.0673
#   • MAX_DPD_120_150_D: 1.7883
#   • MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED: -6879.4091
#   • MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS: -70193.9385
#
#
# ========================================================================================================================
# CLUSTER 4
# ========================================================================================================================
#
# 📊 CLUSTER POPULATION:
#   • Train samples: 14,129 (11.47% of train)
#   • val samples: 334 (4.28% of val)
#   • Total samples: 14,463
#
# 🎯 CLUSTER CLASS 1 RATES:
#   • Train Class 1 rate: 0.2815 (28.15%)
#   • val Class 1 rate: 0.3323 (33.23%)
#   • Absolute difference: 0.0508
#   • Relative change: 18.04%
#   • ✓ Class 1 INCREASED by 18.04%
#
# 📈 TOP 10 CLUSTER CENTROID FEATURES (Highest Values):
#   • NUM_MAINMONEYCLICK_61_TO_90_D: 4.2801
#   • NUM_MAINMONEYCLICK_91_TO_120_D: 3.3002
#   • NUM_PAYOUTCREATED_31_TO_60_D: 1.9788
#   • NUM_MAINBILLSCLICK_91_TO_120_D: 0.6575
#   • COUNT_0_DPD_120_150_D: -89721.7926
#   • MAX_DPD_120_150_D: -96856.4992
#   • TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_UNSECURED_AND_CLOSED: -98978.1185
#   • MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE: -99572.3373
#   • MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS: -99687.5868
#   • MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED: -99891.8520
#
# 📉 BOTTOM 10 CLUSTER CENTROID FEATURES (Lowest Values):
#   • NUM_MAINMONEYCLICK_91_TO_120_D: 3.3002
#   • NUM_PAYOUTCREATED_31_TO_60_D: 1.9788
#   • NUM_MAINBILLSCLICK_91_TO_120_D: 0.6575
#   • COUNT_0_DPD_120_150_D: -89721.7926
#   • MAX_DPD_120_150_D: -96856.4992
#   • TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_UNSECURED_AND_CLOSED: -98978.1185
#   • MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE: -99572.3373
#   • MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS: -99687.5868
#   • MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED: -99891.8520
#   • BUREAUSCORE: -99999.0000
#
#
# ========================================================================================================================
# CLUSTER 5
# ========================================================================================================================
#
# 📊 CLUSTER POPULATION:
#   • Train samples: 9,678 (7.86% of train)
#   • val samples: 130 (1.67% of val)
#   • Total samples: 9,808
#
# 🎯 CLUSTER CLASS 1 RATES:
#   • Train Class 1 rate: 0.2979 (29.79%)
#   • val Class 1 rate: 0.3231 (32.31%)
#   • Absolute difference: 0.0252
#   • Relative change: 8.45%
#   • ✓ Class 1 INCREASED by 8.45%
#
# 📈 TOP 10 CLUSTER CENTROID FEATURES (Highest Values):
#   • TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_UNSECURED_AND_CLOSED: 135147.2045
#   • MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE: 14019.0261
#   • BUREAUSCORE: 762.1830
#   • NUM_MAINMONEYCLICK_61_TO_90_D: 19.7466
#   • NUM_MAINMONEYCLICK_91_TO_120_D: 15.3971
#   • NUM_PAYOUTCREATED_31_TO_60_D: 9.2508
#   • NUM_MAINBILLSCLICK_91_TO_120_D: 2.2385
#   • COUNT_0_DPD_120_150_D: 0.0000
#   • MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED: -6709.3303
#   • MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS: -99999.0000
#
# 📉 BOTTOM 10 CLUSTER CENTROID FEATURES (Lowest Values):
#   • MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE: 14019.0261
#   • BUREAUSCORE: 762.1830
#   • NUM_MAINMONEYCLICK_61_TO_90_D: 19.7466
#   • NUM_MAINMONEYCLICK_91_TO_120_D: 15.3971
#   • NUM_PAYOUTCREATED_31_TO_60_D: 9.2508
#   • NUM_MAINBILLSCLICK_91_TO_120_D: 2.2385
#   • COUNT_0_DPD_120_150_D: 0.0000
#   • MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED: -6709.3303
#   • MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS: -99999.0000
#   • MAX_DPD_120_150_D: -99999.0000
#
#
# ========================================================================================================================
# CLUSTER 6
# ========================================================================================================================
#
# 📊 CLUSTER POPULATION:
#   • Train samples: 2 (0.00% of train)
#   • val samples: 0 (0.00% of val)
#   • Total samples: 2
#
# 🎯 CLUSTER CLASS 1 RATES:
#   • Train Class 1 rate: 0.5000 (50.00%)
#   • val Class 1 rate: 0.0000 (0.00%)
#   • Absolute difference: -0.5000
#   • Relative change: -100.00%
#   • ⚠️  Class 1 DECREASED by 100.00%
#
# 📈 TOP 10 CLUSTER CENTROID FEATURES (Highest Values):
#   • TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_UNSECURED_AND_CLOSED: 1000082499.0000
#   • MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE: 49729.5000
#   • BUREAUSCORE: 739.0000
#   • MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED: 258.0000
#   • NUM_MAINMONEYCLICK_91_TO_120_D: 2.0000
#   • NUM_MAINBILLSCLICK_91_TO_120_D: 1.5000
#   • NUM_MAINMONEYCLICK_61_TO_90_D: 0.5000
#   • NUM_PAYOUTCREATED_31_TO_60_D: 0.0000
#   • MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS: -99999.0000
#   • COUNT_0_DPD_120_150_D: -99999.0000
#
# 📉 BOTTOM 10 CLUSTER CENTROID FEATURES (Lowest Values):
#   • MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE: 49729.5000
#   • BUREAUSCORE: 739.0000
#   • MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED: 258.0000
#   • NUM_MAINMONEYCLICK_91_TO_120_D: 2.0000
#   • NUM_MAINBILLSCLICK_91_TO_120_D: 1.5000
#   • NUM_MAINMONEYCLICK_61_TO_90_D: 0.5000
#   • NUM_PAYOUTCREATED_31_TO_60_D: 0.0000
#   • MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS: -99999.0000
#   • COUNT_0_DPD_120_150_D: -99999.0000
#   • MAX_DPD_120_150_D: -99999.0000
#
#
# ========================================================================================================================
# CLUSTER 7
# ========================================================================================================================
#
# 📊 CLUSTER POPULATION:
#   • Train samples: 818 (0.66% of train)
#   • val samples: 63 (0.81% of val)
#   • Total samples: 881
#
# 🎯 CLUSTER CLASS 1 RATES:
#   • Train Class 1 rate: 0.3154 (31.54%)
#   • val Class 1 rate: 0.2857 (28.57%)
#   • Absolute difference: -0.0297
#   • Relative change: -9.41%
#   • ⚠️  Class 1 DECREASED by 9.41%
#
# 📈 TOP 10 CLUSTER CENTROID FEATURES (Highest Values):
#   • MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE: 610946.2689
#   • TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_UNSECURED_AND_CLOSED: 170061.4495
#   • BUREAUSCORE: 638.1326
#   • NUM_MAINMONEYCLICK_61_TO_90_D: -2521.4596
#   • NUM_MAINMONEYCLICK_91_TO_120_D: -2522.6402
#   • NUM_PAYOUTCREATED_31_TO_60_D: -2523.1604
#   • NUM_MAINBILLSCLICK_91_TO_120_D: -2524.8068
#   • MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED: -23883.6667
#   • MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS: -84972.6073
#   • COUNT_0_DPD_120_150_D: -86614.3927
#
# 📉 BOTTOM 10 CLUSTER CENTROID FEATURES (Lowest Values):
#   • TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_UNSECURED_AND_CLOSED: 170061.4495
#   • BUREAUSCORE: 638.1326
#   • NUM_MAINMONEYCLICK_61_TO_90_D: -2521.4596
#   • NUM_MAINMONEYCLICK_91_TO_120_D: -2522.6402
#   • NUM_PAYOUTCREATED_31_TO_60_D: -2523.1604
#   • NUM_MAINBILLSCLICK_91_TO_120_D: -2524.8068
#   • MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED: -23883.6667
#   • MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS: -84972.6073
#   • COUNT_0_DPD_120_150_D: -86614.3927
#   • MAX_DPD_120_150_D: -94948.4141
#
#
# ========================================================================================================================
# CLUSTER 8
# ========================================================================================================================
#
# 📊 CLUSTER POPULATION:
#   • Train samples: 13,939 (11.31% of train)
#   • val samples: 787 (10.09% of val)
#   • Total samples: 14,726
#
# 🎯 CLUSTER CLASS 1 RATES:
#   • Train Class 1 rate: 0.3492 (34.92%)
#   • val Class 1 rate: 0.3367 (33.67%)
#   • Absolute difference: -0.0124
#   • Relative change: -3.56%
#   • ⚠️  Class 1 DECREASED by 3.56%
#
# 📈 TOP 10 CLUSTER CENTROID FEATURES (Highest Values):
#   • BUREAUSCORE: 785.1154
#   • NUM_MAINMONEYCLICK_61_TO_90_D: 3.9946
#   • NUM_MAINMONEYCLICK_91_TO_120_D: 3.0019
#   • NUM_PAYOUTCREATED_31_TO_60_D: 1.9203
#   • NUM_MAINBILLSCLICK_91_TO_120_D: 0.6193
#   • TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_UNSECURED_AND_CLOSED: -5874.0141
#   • MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE: -65112.6155
#   • COUNT_0_DPD_120_150_D: -90514.9138
#   • MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED: -99948.3674
#   • MAX_DPD_120_150_D: -99999.0000
#
# 📉 BOTTOM 10 CLUSTER CENTROID FEATURES (Lowest Values):
#   • NUM_MAINMONEYCLICK_61_TO_90_D: 3.9946
#   • NUM_MAINMONEYCLICK_91_TO_120_D: 3.0019
#   • NUM_PAYOUTCREATED_31_TO_60_D: 1.9203
#   • NUM_MAINBILLSCLICK_91_TO_120_D: 0.6193
#   • TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_UNSECURED_AND_CLOSED: -5874.0141
#   • MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE: -65112.6155
#   • COUNT_0_DPD_120_150_D: -90514.9138
#   • MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED: -99948.3674
#   • MAX_DPD_120_150_D: -99999.0000
#   • MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS: -99999.0000
#
#
# ========================================================================================================================
# CLUSTER 9
# ========================================================================================================================
#
# 📊 CLUSTER POPULATION:
#   • Train samples: 1 (0.00% of train)
#   • val samples: 0 (0.00% of val)
#   • Total samples: 1
#
# 🎯 CLUSTER CLASS 1 RATES:
#   • Train Class 1 rate: 0.0000 (0.00%)
#   • val Class 1 rate: 0.0000 (0.00%)
#   • Absolute difference: 0.0000
#   • Relative change: 0.00%
#   • ✓ Class 1 INCREASED by 0.00%
#
# 📈 TOP 10 CLUSTER CENTROID FEATURES (Highest Values):
#   • MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE: 15937383.0000
#   • TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_UNSECURED_AND_CLOSED: 8689.0000
#   • BUREAUSCORE: 728.0000
#   • MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED: 21.0000
#   • MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS: 0.0000
#   • NUM_MAINMONEYCLICK_91_TO_120_D: 0.0000
#   • NUM_PAYOUTCREATED_31_TO_60_D: 0.0000
#   • NUM_MAINMONEYCLICK_61_TO_90_D: 0.0000
#   • NUM_MAINBILLSCLICK_91_TO_120_D: -0.0000
#   • COUNT_0_DPD_120_150_D: -99999.0000
#
# 📉 BOTTOM 10 CLUSTER CENTROID FEATURES (Lowest Values):
#   • TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_UNSECURED_AND_CLOSED: 8689.0000
#   • BUREAUSCORE: 728.0000
#   • MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED: 21.0000
#   • MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS: 0.0000
#   • NUM_MAINMONEYCLICK_91_TO_120_D: 0.0000
#   • NUM_PAYOUTCREATED_31_TO_60_D: 0.0000
#   • NUM_MAINMONEYCLICK_61_TO_90_D: 0.0000
#   • NUM_MAINBILLSCLICK_91_TO_120_D: -0.0000
#   • COUNT_0_DPD_120_150_D: -99999.0000
#   • MAX_DPD_120_150_D: -99999.0000
#
#
# ========================================================================================================================
# CLUSTER SUMMARY TABLE
# ========================================================================================================================
#  cluster_id  n_train  n_val  train_class1_rate  val_class1_rate  class1_diff  class1_diff_pct
#           0    17647   2412           0.314614         0.296434    -0.018180        -5.778467
#           1     9571    486           0.384704         0.333333    -0.051370       -13.353250
#           2    37461   1274           0.304183         0.328885     0.024702         8.120895
#           3    19962   2316           0.290903         0.267271    -0.023632        -8.123526
#           4    14129    334           0.281549         0.332335     0.050787        18.038358
#           5     9678    130           0.297892         0.323077     0.025185         8.454334
#           6        2      0           0.500000         0.000000    -0.500000      -100.000000
#           7      818     63           0.315403         0.285714    -0.029689        -9.413068
#           8    13939    787           0.349164         0.336722    -0.012442        -3.563506
#           9        1      0           0.000000         0.000000     0.000000         0.000000
# ========================================================================================================================
# ✓ Cluster characteristics analysis complete

# %% [markdown]
# ## Step 3: Cluster-wise Decision Tree Analysis (Leaf Characteristics)

# %%
def format_bounded_conditions(path_conditions, X_leaf_data, feature_names):
    """Convert path conditions to bounded ranges, adding data bounds where tree bounds missing"""
    feature_bounds = {}
    for cond in path_conditions:
        if ' <= ' in cond:
            feat, val = cond.split(' <= ')
            val = float(val)
            if feat not in feature_bounds:
                feature_bounds[feat] = {'lower': None, 'upper': None}
            if feature_bounds[feat]['upper'] is None or val < feature_bounds[feat]['upper']:
                feature_bounds[feat]['upper'] = val
        elif ' > ' in cond:
            feat, val = cond.split(' > ')
            val = float(val)
            if feat not in feature_bounds:
                feature_bounds[feat] = {'lower': None, 'upper': None}
            if feature_bounds[feat]['lower'] is None or val > feature_bounds[feat]['lower']:
                feature_bounds[feat]['lower'] = val
    
    # Add empirical bounds from actual leaf data
    for feat, bounds in feature_bounds.items():
        feat_idx = feature_names.index(feat)
        feat_data = X_leaf_data[:, feat_idx]
        
        if bounds['lower'] is None:
            bounds['lower'] = feat_data.min()
        if bounds['upper'] is None:
            bounds['upper'] = feat_data.max()
    
    formatted = []
    for feat, bounds in sorted(feature_bounds.items()):
        lower = bounds['lower']
        upper = bounds['upper']
        formatted.append(f"{lower:.4f} < {feat} <= {upper:.4f}")
    
    return formatted

def extract_decision_paths(tree, feature_names, X, y_class1, is_val):
    """
    Extract all decision paths from tree and analyze Class 1 degradation.
    Returns DataFrame with comprehensive path statistics.
    Formats conditions as bounded ranges using tree splits + data bounds.
    """
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]
    
    paths = []
    
    def recurse(node, path_conditions):
        """Recursively traverse tree and collect paths to leaves"""
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            
            left_condition = f"{name} <= {threshold:.4f}"
            recurse(tree_.children_left[node], path_conditions + [left_condition])
            
            right_condition = f"{name} > {threshold:.4f}"
            recurse(tree_.children_right[node], path_conditions + [right_condition])
        else:
            leaf_idx = tree.apply(X) == node
            leaf_is_val = is_val[leaf_idx]
            leaf_y_class1 = y_class1[leaf_idx]
            X_leaf = X[leaf_idx]
            
            n_train = (leaf_is_val == 0).sum()
            n_val = (leaf_is_val == 1).sum()
            val_purity = n_val / (n_train + n_val) if (n_train + n_val) > 0 else 0
            
            train_mask = leaf_is_val == 0
            val_mask = leaf_is_val == 1
            
            train_class1_rate = leaf_y_class1[train_mask].mean() if train_mask.sum() > 0 else 0
            val_class1_rate = leaf_y_class1[val_mask].mean() if val_mask.sum() > 0 else 0
            
            class1_diff = val_class1_rate - train_class1_rate
            impact_score = class1_diff * (n_train + n_val)
            
            bounded_conditions = format_bounded_conditions(path_conditions, X_leaf, feature_names)
            
            paths.append({
                'node_id': node,
                'path': ' AND '.join(bounded_conditions) if bounded_conditions else 'root',
                'bounded_conditions': bounded_conditions,
                'n_conditions': len(bounded_conditions),
                'n_samples': n_train + n_val,
                'n_train': n_train,
                'n_val': n_val,
                'val_purity': val_purity,
                'train_class1_rate': train_class1_rate,
                'val_class1_rate': val_class1_rate,
                'class1_diff': class1_diff,
                'class1_diff_pct': (class1_diff / train_class1_rate * 100) if train_class1_rate > 0 else 0,
                'impact_score': impact_score
            })
    
    recurse(0, [])
    return pd.DataFrame(paths)


print(f"\n{'='*120}")
print("CLUSTER-WISE DEGRADATION ANALYSIS (LEAF CHARACTERISTICS)")
print(f"{'='*120}\n")

all_cluster_results = []

for cluster_id in range(optimal_n_clusters):
    print(f"\n{'#'*120}")
    print(f"{'#'*120}")
    print(f"ANALYZING CLUSTER {cluster_id}")
    print(f"{'#'*120}")
    print(f"{'#'*120}\n")
    
    train_cluster_mask = X_train_with_cluster['cluster'] == cluster_id
    val_cluster_mask = X_val_with_cluster['cluster'] == cluster_id
    
    X_train_cluster = X_train[train_cluster_mask].copy()
    y_train_cluster = y_train_with_cluster[train_cluster_mask].copy()
    X_val_cluster = X_val[val_cluster_mask].copy()
    y_val_cluster = y_val_with_cluster[val_cluster_mask].copy()
    
    if len(X_train_cluster) < 100 or len(X_val_cluster) < 30:
        print(f"⚠️  Skipping Cluster {cluster_id}: Insufficient samples")
        print(f"   Train: {len(X_train_cluster)}, val: {len(X_val_cluster)}")
        continue
    
    print(f"✓ Cluster {cluster_id} samples: Train={len(X_train_cluster):,}, val={len(X_val_cluster):,}")
    
    is_val_train_cluster = np.zeros(len(X_train_cluster))
    is_val_val_cluster = np.ones(len(X_val_cluster))
    
    X_combined_cluster = pd.concat([X_train_cluster, X_val_cluster], axis=0, ignore_index=True)
    y_combined_class1_cluster = pd.concat([y_train_cluster, y_val_cluster], axis=0, ignore_index=True)
    is_val_combined_cluster = np.concatenate([is_val_train_cluster, is_val_val_cluster])
    
    expected_val_pct_cluster = len(X_val_cluster) / len(X_combined_cluster)
    
    min_samples_cluster = max(50, int(0.01 * len(X_combined_cluster)))
    
    tree_model_cluster = DecisionTreeClassifier(
        max_depth=8,
        min_samples_leaf=min_samples_cluster,
        criterion='gini',
        random_state=42
    )
    
    tree_model_cluster.fit(X_combined_cluster, is_val_combined_cluster)
    
    feature_importance_cluster = pd.DataFrame({
        'feature': features,
        'importance': tree_model_cluster.feature_importances_
    }).sort_values('importance', ascending=False)
    
    print(f"\n✓ Decision tree fitted for Cluster {cluster_id}")
    print(f"  - Tree depth: {tree_model_cluster.get_depth()}")
    print(f"  - Number of leaves: {tree_model_cluster.get_n_leaves()}")
    print(f"  - Min samples per leaf: {min_samples_cluster}")
    print(f"\n📊 Top 10 features distinguishing val from train in Cluster {cluster_id}:")
    print(feature_importance_cluster.head(10).to_string(index=False))
    
    df_paths_cluster = extract_decision_paths(
        tree_model_cluster,
        features,
        X_combined_cluster.values,
        y_combined_class1_cluster.values,
        is_val_combined_cluster
    )
    
    min_samples_per_split = 20
    df_paths_valid_cluster = df_paths_cluster[
        (df_paths_cluster['n_train'] >= min_samples_per_split) & 
        (df_paths_cluster['n_val'] >= min_samples_per_split)
    ].copy()
    
    if len(df_paths_valid_cluster) == 0:
        print(f"\n⚠️  No valid paths found for Cluster {cluster_id}")
        continue
    
    df_paths_valid_cluster['val_overrep_%'] = (df_paths_valid_cluster['val_purity'] / expected_val_pct_cluster - 1) * 100
    df_paths_valid_cluster['pct_of_train'] = df_paths_valid_cluster['n_train'] / len(X_train_cluster) * 100
    df_paths_valid_cluster['pct_of_val'] = df_paths_valid_cluster['n_val'] / len(X_val_cluster) * 100
    df_paths_valid_cluster['cluster_id'] = cluster_id
    
    df_ranked_cluster = df_paths_valid_cluster.sort_values('impact_score', ascending=True).reset_index(drop=True)
    
    print(f"\n{'='*120}")
    print(f"LEAF CHARACTERISTICS FOR CLUSTER {cluster_id}")
    print(f"{'='*120}")
    print(f"✓ Valid leaf paths: {len(df_paths_valid_cluster)}")
    print(f"\nTOP 5 LEAVES WITH HIGHEST CLASS 1 SUPPRESSION:\n")
    
    for idx, row in df_ranked_cluster.head(5).iterrows():
        print(f"\n{'-'*120}")
        print(f"Cluster {cluster_id}, Leaf #{idx + 1} | Impact Score: {row['impact_score']:.2f}")
        print(f"{'-'*120}")
        
        print(f"\n📍 Decision Path ({row['n_conditions']} conditions):")
        if row['path'] != 'root':
            conditions = row['path'].split(' AND ')
            for i, cond in enumerate(conditions, 1):
                print(f"  {i}. {cond}")
        else:
            print("  ROOT (no splits)")
        
        print(f"\n📊 Leaf Population:")
        print(f"  • Total samples: {row['n_samples']:,} ({row['n_samples']/len(X_combined_cluster)*100:.2f}% of cluster)")
        print(f"  • Train: {row['n_train']:,} ({row['pct_of_train']:.2f}% of cluster train)")
        print(f"  • val: {row['n_val']:,} ({row['pct_of_val']:.2f}% of cluster val)")
        print(f"  • val purity: {row['val_purity']:.2%} (cluster baseline: {expected_val_pct_cluster:.2%})")
        
        print(f"\n🎯 Leaf Class 1 Analysis:")
        print(f"  • Train Class 1 rate: {row['train_class1_rate']:.4f} ({row['train_class1_rate']*100:.2f}%)")
        print(f"  • val Class 1 rate: {row['val_class1_rate']:.4f} ({row['val_class1_rate']*100:.2f}%)")
        print(f"  • Absolute difference: {row['class1_diff']:.4f}")
        print(f"  • Relative change: {row['class1_diff_pct']:.2f}%")
        
        if row['class1_diff'] < 0:
            print(f"  • ⚠️  Class 1 DECREASED by {abs(row['class1_diff_pct']):.2f}%")
        else:
            print(f"  • ✓ Class 1 INCREASED by {row['class1_diff_pct']:.2f}%")
    
    all_cluster_results.append(df_ranked_cluster)
    
    print(f"\n{'='*120}\n")

print(f"\n{'#'*120}")
print("✓ Cluster-wise degradation analysis complete")
print(f"{'#'*120}\n")
# Out:
# ========================================================================================================================
# CLUSTER-WISE DEGRADATION ANALYSIS (LEAF CHARACTERISTICS)
# ========================================================================================================================
#
#
# ########################################################################################################################
# ########################################################################################################################
# ANALYZING CLUSTER 0
# ########################################################################################################################
# ########################################################################################################################
#
# ✓ Cluster 0 samples: Train=17,647, val=2,412
#
# ✓ Decision tree fitted for Cluster 0
#   - Tree depth: 8
#   - Number of leaves: 49
#   - Min samples per leaf: 200
#
# 📊 Top 10 features distinguishing val from train in Cluster 0:
#                                                           feature  importance
#                                                       BUREAUSCORE    0.293656
#                                     NUM_MAINMONEYCLICK_61_TO_90_D    0.230785
#                  MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED    0.116570
#                                    NUM_MAINMONEYCLICK_91_TO_120_D    0.094499
# TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_UNSECURED_AND_CLOSED    0.071519
#                                    NUM_MAINBILLSCLICK_91_TO_120_D    0.068313
#        RATIO_OF_DISTINCT_BANKS_LOAN_REPAYMENT_LAST_30D_TO_30TO60D    0.033467
#   TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_SECURED_AND_CLOSED    0.013816
#                          MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE    0.013551
#                        MIN_AVAILABLE_BALANCE_90TO120D_SMS_BANKING    0.008474
#
# ========================================================================================================================
# LEAF CHARACTERISTICS FOR CLUSTER 0
# ========================================================================================================================
# ✓ Valid leaf paths: 26
#
# TOP 5 LEAVES WITH HIGHEST CLASS 1 SUPPRESSION:
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 0, Leaf #1 | Impact Score: -113.96
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (8 conditions):
#   1. 521.0000 < BUREAUSCORE <= 773.5000
#   2. 78.5000 < MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED <= 333912.0000
#   3. -367960.0000 < MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE <= 942.5000
#   4. 0.0000 < NUM_MAINBILLSCLICK_91_TO_120_D <= 0.5000
#   5. 0.0000 < NUM_MAINMONEYCLICK_31_TO_60_D <= 0.5000
#   6. 0.0000 < NUM_MAINMONEYCLICK_61_TO_90_D <= 0.5000
#   7. 0.0000 < NUM_MAINMONEYCLICK_91_TO_120_D <= 0.5000
#   8. -99999.0000 < TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_UNSECURED_AND_CLOSED <= 119956.0000
#
# 📊 Leaf Population:
#   • Total samples: 1,212 (6.04% of cluster)
#   • Train: 1,080 (6.12% of cluster train)
#   • val: 132 (5.47% of cluster val)
#   • val purity: 10.89% (cluster baseline: 12.02%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.3213 (32.13%)
#   • val Class 1 rate: 0.2273 (22.73%)
#   • Absolute difference: -0.0940
#   • Relative change: -29.26%
#   • ⚠️  Class 1 DECREASED by 29.26%
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 0, Leaf #2 | Impact Score: -58.78
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (7 conditions):
#   1. 527.0000 < BUREAUSCORE <= 773.5000
#   2. 108.5000 < MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED <= 45460.0000
#   3. 0.0000 < NUM_MAINBILLSCLICK_91_TO_120_D <= 0.5000
#   4. 0.0000 < NUM_MAINMONEYCLICK_61_TO_90_D <= 0.5000
#   5. 0.0000 < NUM_MAINMONEYCLICK_91_TO_120_D <= 0.5000
#   6. 0.7321 < RATIO_OF_DISTINCT_BANKS_LOAN_REPAYMENT_LAST_30D_TO_30TO60D <= 6.0000
#   7. 119956.0000 < TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_UNSECURED_AND_CLOSED <= 7858804.0000
#
# 📊 Leaf Population:
#   • Total samples: 1,271 (6.34% of cluster)
#   • Train: 1,098 (6.22% of cluster train)
#   • val: 173 (7.17% of cluster val)
#   • val purity: 13.61% (cluster baseline: 12.02%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.2832 (28.32%)
#   • val Class 1 rate: 0.2370 (23.70%)
#   • Absolute difference: -0.0462
#   • Relative change: -16.33%
#   • ⚠️  Class 1 DECREASED by 16.33%
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 0, Leaf #3 | Impact Score: -51.26
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (8 conditions):
#   1. -99999.0000 < BUREAUSCORE <= 773.5000
#   2. -99999.0000 < MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED <= 78.5000
#   3. -1121201.1600 < MIN_AVAILABLE_BALANCE_LAST30D_SMS_BANKING <= 2.4950
#   4. 0.0000 < NUM_MAINBILLSCLICK_91_TO_120_D <= 0.5000
#   5. 0.0000 < NUM_MAINMONEYCLICK_61_TO_90_D <= 0.5000
#   6. 0.0000 < NUM_MAINMONEYCLICK_91_TO_120_D <= 0.5000
#   7. -99999.0000 < RATIO_OF_DISTINCT_BANKS_LOAN_REPAYMENT_LAST_30D_TO_30TO60D <= 0.7083
#   8. -99999.0000 < TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_UNSECURED_AND_CLOSED <= 106054.5000
#
# 📊 Leaf Population:
#   • Total samples: 410 (2.04% of cluster)
#   • Train: 324 (1.84% of cluster train)
#   • val: 86 (3.57% of cluster val)
#   • val purity: 20.98% (cluster baseline: 12.02%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.4506 (45.06%)
#   • val Class 1 rate: 0.3256 (32.56%)
#   • Absolute difference: -0.1250
#   • Relative change: -27.75%
#   • ⚠️  Class 1 DECREASED by 27.75%
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 0, Leaf #4 | Impact Score: -35.96
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (8 conditions):
#   1. 585.0000 < BUREAUSCORE <= 773.5000
#   2. -99999.0000 < MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED <= 78.5000
#   3. 0.0000 < NUM_MAINBILLSCLICK_91_TO_120_D <= 0.5000
#   4. 0.0000 < NUM_MAINMONEYCLICK_61_TO_90_D <= 0.5000
#   5. 0.0000 < NUM_MAINMONEYCLICK_91_TO_120_D <= 0.5000
#   6. 0.7083 < RATIO_OF_DISTINCT_BANKS_LOAN_REPAYMENT_LAST_30D_TO_30TO60D <= 5.0000
#   7. 21224.5000 < TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_SECURED_AND_CLOSED <= 12300000.0000
#   8. -99999.0000 < TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_UNSECURED_AND_CLOSED <= 106054.5000
#
# 📊 Leaf Population:
#   • Total samples: 258 (1.29% of cluster)
#   • Train: 226 (1.28% of cluster train)
#   • val: 32 (1.33% of cluster val)
#   • val purity: 12.40% (cluster baseline: 12.02%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.3894 (38.94%)
#   • val Class 1 rate: 0.2500 (25.00%)
#   • Absolute difference: -0.1394
#   • Relative change: -35.80%
#   • ⚠️  Class 1 DECREASED by 35.80%
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 0, Leaf #5 | Impact Score: -30.18
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (5 conditions):
#   1. 2.5000 < ACCOUNT_OPENED_IN_LAST_180_DAYS <= 22.0000
#   2. 502.0000 < BUREAUSCORE <= 773.5000
#   3. -99999.0000 < MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED <= 78.5000
#   4. 0.0000 < NUM_MAINMONEYCLICK_61_TO_90_D <= 0.5000
#   5. 0.5000 < NUM_MAINMONEYCLICK_91_TO_120_D <= 30.0000
#
# 📊 Leaf Population:
#   • Total samples: 203 (1.01% of cluster)
#   • Train: 160 (0.91% of cluster train)
#   • val: 43 (1.78% of cluster val)
#   • val purity: 21.18% (cluster baseline: 12.02%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.3812 (38.12%)
#   • val Class 1 rate: 0.2326 (23.26%)
#   • Absolute difference: -0.1487
#   • Relative change: -39.00%
#   • ⚠️  Class 1 DECREASED by 39.00%
#
# ========================================================================================================================
#
#
# ########################################################################################################################
# ########################################################################################################################
# ANALYZING CLUSTER 1
# ########################################################################################################################
# ########################################################################################################################
#
# ✓ Cluster 1 samples: Train=9,571, val=486
#
# ✓ Decision tree fitted for Cluster 1
#   - Tree depth: 8
#   - Number of leaves: 40
#   - Min samples per leaf: 100
#
# 📊 Top 10 features distinguishing val from train in Cluster 1:
#                                                             feature  importance
#                                                         BUREAUSCORE    0.329964
#                              MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS    0.317046
#                    MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED    0.113234
#                         TOTAL_REPAYMENT_TENURE_UNSECURED_AND_CLOSED    0.072247
#               RATIO_CREDIT_GIVEN_LIFETIME_CREDIT_RECOVERED_LIFETIME    0.055311
#     TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_SECURED_AND_CLOSED    0.021971
# AVG_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_UNSECURED_AND_CLOSED_P10    0.016313
#                            MAX_DAYS_PAST_DUE_CLOSED_450_TO_480_DAYS    0.012803
#                                            NUM_SMS_180D_SMS_BANKING    0.009810
#                            MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE    0.009478
#
# ========================================================================================================================
# LEAF CHARACTERISTICS FOR CLUSTER 1
# ========================================================================================================================
# ✓ Valid leaf paths: 7
#
# TOP 5 LEAVES WITH HIGHEST CLASS 1 SUPPRESSION:
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 1, Leaf #1 | Impact Score: -25.49
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (6 conditions):
#   1. -99999.0000 < AVG_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_UNSECURED_AND_CLOSED_P10 <= 2213.6646
#   2. 521.0000 < BUREAUSCORE <= 767.5000
#   3. -49999.5000 < MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS <= 900.0000
#   4. 84.5000 < MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED <= 3929.0000
#   5. 1174.0000 < NUM_SMS_180D_SMS_BANKING <= 16715.0000
#   6. -99999.0000 < TOTAL_REPAYMENT_TENURE_UNSECURED_AND_CLOSED <= 43.5000
#
# 📊 Leaf Population:
#   • Total samples: 167 (1.66% of cluster)
#   • Train: 139 (1.45% of cluster train)
#   • val: 28 (5.76% of cluster val)
#   • val purity: 16.77% (cluster baseline: 4.83%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.3669 (36.69%)
#   • val Class 1 rate: 0.2143 (21.43%)
#   • Absolute difference: -0.1526
#   • Relative change: -41.60%
#   • ⚠️  Class 1 DECREASED by 41.60%
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 1, Leaf #2 | Impact Score: -18.97
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (5 conditions):
#   1. 601.0000 < BUREAUSCORE <= 767.5000
#   2. -49999.5000 < MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS <= 73.0000
#   3. -99999.0000 < MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED <= 84.5000
#   4. 1.0303 < RATIO_CREDIT_GIVEN_LIFETIME_CREDIT_RECOVERED_LIFETIME <= 7420.0000
#   5. -99999.0000 < TOTAL_REPAYMENT_TENURE_UNSECURED_AND_CLOSED <= 43.5000
#
# 📊 Leaf Population:
#   • Total samples: 102 (1.01% of cluster)
#   • Train: 45 (0.47% of cluster train)
#   • val: 57 (11.73% of cluster val)
#   • val purity: 55.88% (cluster baseline: 4.83%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.4667 (46.67%)
#   • val Class 1 rate: 0.2807 (28.07%)
#   • Absolute difference: -0.1860
#   • Relative change: -39.85%
#   • ⚠️  Class 1 DECREASED by 39.85%
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 1, Leaf #3 | Impact Score: -11.84
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (4 conditions):
#   1. 562.0000 < BUREAUSCORE <= 767.5000
#   2. -49999.5000 < MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS <= 119.0000
#   3. -99999.0000 < TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_SECURED_AND_CLOSED <= 330591.0000
#   4. 43.5000 < TOTAL_REPAYMENT_TENURE_UNSECURED_AND_CLOSED <= 346.0000
#
# 📊 Leaf Population:
#   • Total samples: 175 (1.74% of cluster)
#   • Train: 82 (0.86% of cluster train)
#   • val: 93 (19.14% of cluster val)
#   • val purity: 53.14% (cluster baseline: 4.83%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.3902 (39.02%)
#   • val Class 1 rate: 0.3226 (32.26%)
#   • Absolute difference: -0.0677
#   • Relative change: -17.34%
#   • ⚠️  Class 1 DECREASED by 17.34%
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 1, Leaf #4 | Impact Score: -6.80
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (5 conditions):
#   1. -99999.0000 < BUREAUSCORE <= 767.5000
#   2. -49999.5000 < MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS <= 83.0000
#   3. -99999.0000 < MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED <= 84.5000
#   4. -99999.0000 < RATIO_CREDIT_GIVEN_LIFETIME_CREDIT_RECOVERED_LIFETIME <= 1.0303
#   5. -99999.0000 < TOTAL_REPAYMENT_TENURE_UNSECURED_AND_CLOSED <= 43.5000
#
# 📊 Leaf Population:
#   • Total samples: 165 (1.64% of cluster)
#   • Train: 123 (1.29% of cluster train)
#   • val: 42 (8.64% of cluster val)
#   • val purity: 25.45% (cluster baseline: 4.83%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.3984 (39.84%)
#   • val Class 1 rate: 0.3571 (35.71%)
#   • Absolute difference: -0.0412
#   • Relative change: -10.35%
#   • ⚠️  Class 1 DECREASED by 10.35%
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 1, Leaf #5 | Impact Score: -0.76
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (4 conditions):
#   1. 493.0000 < BUREAUSCORE <= 750.5000
#   2. -99999.0000 < MAX_DAYS_PAST_DUE_ACTIVE_30_TO_60_DAYS <= -49999.5000
#   3. -49999.5000 < MAX_DAYS_PAST_DUE_CLOSED_450_TO_480_DAYS <= 900.0000
#   4. -99999.0000 < MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED <= 73.5000
#
# 📊 Leaf Population:
#   • Total samples: 170 (1.69% of cluster)
#   • Train: 125 (1.31% of cluster train)
#   • val: 45 (9.26% of cluster val)
#   • val purity: 26.47% (cluster baseline: 4.83%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.3600 (36.00%)
#   • val Class 1 rate: 0.3556 (35.56%)
#   • Absolute difference: -0.0044
#   • Relative change: -1.23%
#   • ⚠️  Class 1 DECREASED by 1.23%
#
# ========================================================================================================================
#
#
# ########################################################################################################################
# ########################################################################################################################
# ANALYZING CLUSTER 2
# ########################################################################################################################
# ########################################################################################################################
#
# ✓ Cluster 2 samples: Train=37,461, val=1,274
#
# ✓ Decision tree fitted for Cluster 2
#   - Tree depth: 8
#   - Number of leaves: 47
#   - Min samples per leaf: 387
#
# 📊 Top 10 features distinguishing val from train in Cluster 2:
#                                                         feature  importance
#                                                     BUREAUSCORE    0.275972
#                MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED    0.244362
#                        MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE    0.128713
#                                   NUM_MAINMONEYCLICK_61_TO_90_D    0.083588
#                                   NUM_MAINMONEYCLICK_31_TO_60_D    0.074908
#                        MAX_DAYS_PAST_DUE_CLOSED_330_TO_360_DAYS    0.039060
#                                             AVG_AMOUNT_PAST_DUE    0.032233
#                     TOTAL_AVAILABLE_BALANCE_30TO60D_SMS_BANKING    0.023695
# TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_SECURED_AND_CLOSED    0.021062
#                                TOTAL_REPAYMENT_TENURE_UNSECURED    0.016743
#
# ========================================================================================================================
# LEAF CHARACTERISTICS FOR CLUSTER 2
# ========================================================================================================================
# ✓ Valid leaf paths: 17
#
# TOP 5 LEAVES WITH HIGHEST CLASS 1 SUPPRESSION:
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 2, Leaf #1 | Impact Score: -105.95
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (4 conditions):
#   1. 760.5000 < BUREAUSCORE <= 783.5000
#   2. -49999.5000 < MAX_DAYS_PAST_DUE_ACTIVE_UNSECURED_180_TO_210_DAYS <= 60.0000
#   3. 31.0000 < MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED <= 100.5000
#   4. -99999.0000 < MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE <= 8070.5000
#
# 📊 Leaf Population:
#   • Total samples: 650 (1.68% of cluster)
#   • Train: 628 (1.68% of cluster train)
#   • val: 22 (1.73% of cluster val)
#   • val purity: 3.38% (cluster baseline: 3.29%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.2994 (29.94%)
#   • val Class 1 rate: 0.1364 (13.64%)
#   • Absolute difference: -0.1630
#   • Relative change: -54.45%
#   • ⚠️  Class 1 DECREASED by 54.45%
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 2, Leaf #2 | Impact Score: -85.45
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (8 conditions):
#   1. 519.0000 < BUREAUSCORE <= 760.5000
#   2. 72.5000 < MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED <= 45199.0000
#   3. -203230.0000 < MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE <= 4293.5000
#   4. 0.0000 < NUM_MAINMONEYCLICK_31_TO_60_D <= 0.5000
#   5. 0.0000 < NUM_MAINMONEYCLICK_61_TO_90_D <= 0.5000
#   6. -99999.0000 < TOTAL_DEBIT_AMOUNT_LAST30D_CC_SMS_BANKING <= 222.0000
#   7. 307046.7031 < TOTAL_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_UNSECURED_AND_ACTIVE_AVG <= 7993287786.7412
#   8. -99999.0000 < TOTAL_REPAYMENT_TENURE_UNSECURED_AND_CLOSED <= 73.5000
#
# 📊 Leaf Population:
#   • Total samples: 1,013 (2.62% of cluster)
#   • Train: 981 (2.62% of cluster train)
#   • val: 32 (2.51% of cluster val)
#   • val purity: 3.16% (cluster baseline: 3.29%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.3344 (33.44%)
#   • val Class 1 rate: 0.2500 (25.00%)
#   • Absolute difference: -0.0844
#   • Relative change: -25.23%
#   • ⚠️  Class 1 DECREASED by 25.23%
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 2, Leaf #3 | Impact Score: -74.79
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (3 conditions):
#   1. 548.0000 < BUREAUSCORE <= 760.5000
#   2. -99999.0000 < MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED <= 72.5000
#   3. 0.5000 < NUM_MAINMONEYCLICK_61_TO_90_D <= 177.0000
#
# 📊 Leaf Population:
#   • Total samples: 533 (1.38% of cluster)
#   • Train: 504 (1.35% of cluster train)
#   • val: 29 (2.28% of cluster val)
#   • val purity: 5.44% (cluster baseline: 3.29%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.3472 (34.72%)
#   • val Class 1 rate: 0.2069 (20.69%)
#   • Absolute difference: -0.1403
#   • Relative change: -40.41%
#   • ⚠️  Class 1 DECREASED by 40.41%
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 2, Leaf #4 | Impact Score: -69.57
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (7 conditions):
#   1. -99999.0000 < AVG_AMOUNT_PAST_DUE <= 0.0767
#   2. 489.0000 < BUREAUSCORE <= 760.5000
#   3. 72.5000 < MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED <= 45457.0000
#   4. 4293.5000 < MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE <= 311902.0000
#   5. 0.0000 < NUM_MAINMONEYCLICK_31_TO_60_D <= 0.5000
#   6. -7668004.9400 < TOTAL_AVAILABLE_BALANCE_30TO60D_SMS_BANKING <= 861345.6562
#   7. 0.0000 < TOTAL_REPAYMENT_TENURE_UNSECURED <= 64.5000
#
# 📊 Leaf Population:
#   • Total samples: 768 (1.98% of cluster)
#   • Train: 656 (1.75% of cluster train)
#   • val: 112 (8.79% of cluster val)
#   • val purity: 14.58% (cluster baseline: 3.29%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.3674 (36.74%)
#   • val Class 1 rate: 0.2768 (27.68%)
#   • Absolute difference: -0.0906
#   • Relative change: -24.66%
#   • ⚠️  Class 1 DECREASED by 24.66%
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 2, Leaf #5 | Impact Score: -67.37
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (4 conditions):
#   1. 568.0000 < BUREAUSCORE <= 760.5000
#   2. 5.0000 < MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED <= 72.5000
#   3. -99999.0000 < MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE <= 1075.0000
#   4. 0.0000 < NUM_MAINMONEYCLICK_61_TO_90_D <= 0.5000
#
# 📊 Leaf Population:
#   • Total samples: 436 (1.13% of cluster)
#   • Train: 390 (1.04% of cluster train)
#   • val: 46 (3.61% of cluster val)
#   • val purity: 10.55% (cluster baseline: 3.29%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.4154 (41.54%)
#   • val Class 1 rate: 0.2609 (26.09%)
#   • Absolute difference: -0.1545
#   • Relative change: -37.20%
#   • ⚠️  Class 1 DECREASED by 37.20%
#
# ========================================================================================================================
#
#
# ########################################################################################################################
# ########################################################################################################################
# ANALYZING CLUSTER 3
# ########################################################################################################################
# ########################################################################################################################
#
# ✓ Cluster 3 samples: Train=19,962, val=2,316
#
# ✓ Decision tree fitted for Cluster 3
#   - Tree depth: 8
#   - Number of leaves: 36
#   - Min samples per leaf: 222
#
# 📊 Top 10 features distinguishing val from train in Cluster 3:
#                                          feature  importance
#                     NUM_PAYOUTCREATED_31_TO_60_D    0.236399
#                     TOTAL_OVERDUE_AMOUNT_60TO90D    0.226910
#               DISTINCT_BANKS_EMI_OVERDUE_60TO90D    0.206869
#                   NUM_MAINMONEYCLICK_91_TO_120_D    0.123582
#                                      BUREAUSCORE    0.048914
# MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED    0.031940
#                   NUM_MAINBILLSCLICK_91_TO_120_D    0.026692
#                   TOTAL_OVERDUE_AMOUNT_120TO150D    0.026385
#             NUM_SMS_WITH_OVERDUE_AMOUNT_90TO120D    0.019330
#              NUM_SMS_WITH_OVERDUE_AMOUNT_60TO90D    0.016641
#
# ========================================================================================================================
# LEAF CHARACTERISTICS FOR CLUSTER 3
# ========================================================================================================================
# ✓ Valid leaf paths: 20
#
# TOP 5 LEAVES WITH HIGHEST CLASS 1 SUPPRESSION:
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 3, Leaf #1 | Impact Score: -72.06
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (5 conditions):
#   1. 0.0000 < DISTINCT_BANKS_EMI_OVERDUE_60TO90D <= 1.5000
#   2. 0.5000 < NUM_NOCOUNTERPARTYPAYMENTCOMPLETED_121_TO_150_D <= 35.0000
#   3. 0.0000 < NUM_PAYOUTCREATED_31_TO_60_D <= 0.5000
#   4. 0.5000 < NUM_UNIQUE_LOAN_OVERDUE_30D_SMS_BANKING <= 7.0000
#   5. 103.5000 < TOTAL_OVERDUE_AMOUNT_60TO90D <= 7968426.0000
#
# 📊 Leaf Population:
#   • Total samples: 417 (1.87% of cluster)
#   • Train: 397 (1.99% of cluster train)
#   • val: 20 (0.86% of cluster val)
#   • val purity: 4.80% (cluster baseline: 10.40%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.3728 (37.28%)
#   • val Class 1 rate: 0.2000 (20.00%)
#   • Absolute difference: -0.1728
#   • Relative change: -46.35%
#   • ⚠️  Class 1 DECREASED by 46.35%
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 3, Leaf #2 | Impact Score: -28.93
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (4 conditions):
#   1. 0.0000 < DISTINCT_BANKS_EMI_OVERDUE_60TO90D <= 1.5000
#   2. 0.0000 < NUM_NOCOUNTERPARTYPAYMENTCOMPLETED_121_TO_150_D <= 0.5000
#   3. 0.0000 < NUM_PAYOUTCREATED_31_TO_60_D <= 0.5000
#   4. 103.5000 < TOTAL_OVERDUE_AMOUNT_60TO90D <= 7693089.0000
#
# 📊 Leaf Population:
#   • Total samples: 248 (1.11% of cluster)
#   • Train: 226 (1.13% of cluster train)
#   • val: 22 (0.95% of cluster val)
#   • val purity: 8.87% (cluster baseline: 10.40%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.3894 (38.94%)
#   • val Class 1 rate: 0.2727 (27.27%)
#   • Absolute difference: -0.1167
#   • Relative change: -29.96%
#   • ⚠️  Class 1 DECREASED by 29.96%
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 3, Leaf #3 | Impact Score: -22.83
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (6 conditions):
#   1. 577.0000 < BUREAUSCORE <= 784.5000
#   2. -99999.0000 < DISTINCT_BANKS_EMI_OVERDUE_60TO90D <= 0.5000
#   3. 0.5000 < NUM_MAINBILLSCLICK_91_TO_120_D <= 268.0000
#   4. 0.0000 < NUM_MAINMONEYCLICK_91_TO_120_D <= 0.5000
#   5. 0.0000 < NUM_PAYOUTCREATED_31_TO_60_D <= 0.5000
#   6. -99999.0000 < TOTAL_OVERDUE_AMOUNT_60TO90D <= 103.5000
#
# 📊 Leaf Population:
#   • Total samples: 333 (1.49% of cluster)
#   • Train: 105 (0.53% of cluster train)
#   • val: 228 (9.84% of cluster val)
#   • val purity: 68.47% (cluster baseline: 10.40%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.2571 (25.71%)
#   • val Class 1 rate: 0.1886 (18.86%)
#   • Absolute difference: -0.0685
#   • Relative change: -26.66%
#   • ⚠️  Class 1 DECREASED by 26.66%
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 3, Leaf #4 | Impact Score: -19.67
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (5 conditions):
#   1. 0.5000 < DISTINCT_BANKS_EMI_OVERDUE_60TO90D <= 3.0000
#   2. -99999.0000 < MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED <= 79.5000
#   3. 0.5000 < NUM_MAINMONEYCLICK_91_TO_120_D <= 101.0000
#   4. 0.0000 < NUM_PAYOUTCREATED_31_TO_60_D <= 0.5000
#   5. 0.0000 < TOTAL_OVERDUE_AMOUNT_60TO90D <= 103.5000
#
# 📊 Leaf Population:
#   • Total samples: 392 (1.76% of cluster)
#   • Train: 184 (0.92% of cluster train)
#   • val: 208 (8.98% of cluster val)
#   • val purity: 53.06% (cluster baseline: 10.40%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.3098 (30.98%)
#   • val Class 1 rate: 0.2596 (25.96%)
#   • Absolute difference: -0.0502
#   • Relative change: -16.19%
#   • ⚠️  Class 1 DECREASED by 16.19%
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 3, Leaf #5 | Impact Score: -18.72
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (6 conditions):
#   1. -99999.0000 < DISTINCT_BANKS_EMI_OVERDUE_60TO90D <= 0.5000
#   2. 0.5000 < NUM_MAINMONEYCLICK_91_TO_120_D <= 364.0000
#   3. 0.0000 < NUM_PAYMENTPAYNOWCLICK_91_TO_120_D <= 0.5000
#   4. 22.5000 < NUM_PAYOUTCREATED_121_TO_150_D <= 56.0000
#   5. 0.0000 < NUM_PAYOUTCREATED_31_TO_60_D <= 0.5000
#   6. -99999.0000 < TOTAL_OVERDUE_AMOUNT_60TO90D <= 103.5000
#
# 📊 Leaf Population:
#   • Total samples: 229 (1.03% of cluster)
#   • Train: 157 (0.79% of cluster train)
#   • val: 72 (3.11% of cluster val)
#   • val purity: 31.44% (cluster baseline: 10.40%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.2484 (24.84%)
#   • val Class 1 rate: 0.1667 (16.67%)
#   • Absolute difference: -0.0817
#   • Relative change: -32.91%
#   • ⚠️  Class 1 DECREASED by 32.91%
#
# ========================================================================================================================
#
#
# ########################################################################################################################
# ########################################################################################################################
# ANALYZING CLUSTER 4
# ########################################################################################################################
# ########################################################################################################################
#
# ✓ Cluster 4 samples: Train=14,129, val=334
#
# ✓ Decision tree fitted for Cluster 4
#   - Tree depth: 8
#   - Number of leaves: 33
#   - Min samples per leaf: 144
#
# 📊 Top 10 features distinguishing val from train in Cluster 4:
#                                                feature  importance
#                          NUM_MAINMONEYCLICK_61_TO_90_D    0.168528
#              MAX_AVAILABLE_BALANCE_60TO90D_SMS_BANKING    0.102517
#                            NUM_PAYOUTSETTLED_1_TO_30_D    0.094418
# RATIO_AVG_DEBIT_AMOUNT_AVG_CDT_AMT_LAST30D_SMS_BANKING    0.084959
#                          NUM_MAINMONEYCLICK_31_TO_60_D    0.081688
#                        NUM_MAINBILLSCLICK_121_TO_150_D    0.076134
#  RATIO_CREDIT_GIVEN_LIFETIME_CREDIT_RECOVERED_LIFETIME    0.066445
#                              TOTAL_DUE_AMOUNT_LAST_30D    0.058062
#                         MIN_CURRENT_BALANCE_ACTIVE_MAX    0.044960
#              MIN_AVAILABLE_BALANCE_60TO90D_SMS_BANKING    0.037653
#
# ========================================================================================================================
# LEAF CHARACTERISTICS FOR CLUSTER 4
# ========================================================================================================================
# ✓ Valid leaf paths: 4
#
# TOP 5 LEAVES WITH HIGHEST CLASS 1 SUPPRESSION:
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 4, Leaf #1 | Impact Score: -30.55
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (5 conditions):
#   1. -99999.0000 < MAX_AVAILABLE_BALANCE_60TO90D_SMS_BANKING <= 6132.5500
#   2. 0.5000 < NUM_MAINBILLSCLICK_121_TO_150_D <= 68.0000
#   3. 0.0000 < NUM_MAINMONEYCLICK_31_TO_60_D <= 0.5000
#   4. 0.0000 < NUM_MAINMONEYCLICK_61_TO_90_D <= 0.5000
#   5. 0.0000 < NUM_PAYOUTSETTLED_1_TO_30_D <= 0.5000
#
# 📊 Leaf Population:
#   • Total samples: 213 (1.47% of cluster)
#   • Train: 180 (1.27% of cluster train)
#   • val: 33 (9.88% of cluster val)
#   • val purity: 15.49% (cluster baseline: 2.31%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.3556 (35.56%)
#   • val Class 1 rate: 0.2121 (21.21%)
#   • Absolute difference: -0.1434
#   • Relative change: -40.34%
#   • ⚠️  Class 1 DECREASED by 40.34%
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 4, Leaf #2 | Impact Score: 25.04
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (8 conditions):
#   1. -99999.0000 < MIN_CURRENT_BALANCE_ACTIVE_MAX <= 30369.5000
#   2. 0.0000 < NUM_MAINBILLSCLICK_121_TO_150_D <= 0.5000
#   3. 0.0000 < NUM_MAINMONEYCLICK_31_TO_60_D <= 0.5000
#   4. 0.0000 < NUM_MAINMONEYCLICK_61_TO_90_D <= 0.5000
#   5. 0.0000 < NUM_PAYOUTSETTLED_1_TO_30_D <= 0.5000
#   6. 0.9121 < RATIO_AVG_DEBIT_AMOUNT_AVG_CDT_AMT_LAST30D_SMS_BANKING <= 399.9524
#   7. -99999.0000 < RATIO_CREDIT_GIVEN_LIFETIME_CREDIT_RECOVERED_LIFETIME <= 2.2515
#   8. -99999.0000 < TOTAL_DUE_AMOUNT_LAST_30D <= 2213.5000
#
# 📊 Leaf Population:
#   • Total samples: 901 (6.23% of cluster)
#   • Train: 836 (5.92% of cluster train)
#   • val: 65 (19.46% of cluster val)
#   • val purity: 7.21% (cluster baseline: 2.31%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.2799 (27.99%)
#   • val Class 1 rate: 0.3077 (30.77%)
#   • Absolute difference: 0.0278
#   • Relative change: 9.93%
#   • ✓ Class 1 INCREASED by 9.93%
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 4, Leaf #3 | Impact Score: 29.91
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (7 conditions):
#   1. 0.0000 < NUM_MAINBILLSCLICK_121_TO_150_D <= 0.5000
#   2. 0.0000 < NUM_MAINMONEYCLICK_31_TO_60_D <= 0.5000
#   3. 0.0000 < NUM_MAINMONEYCLICK_61_TO_90_D <= 0.5000
#   4. 0.0000 < NUM_PAYOUTSETTLED_1_TO_30_D <= 0.5000
#   5. 0.9121 < RATIO_AVG_DEBIT_AMOUNT_AVG_CDT_AMT_LAST30D_SMS_BANKING <= 99.1280
#   6. 2.2515 < RATIO_CREDIT_GIVEN_LIFETIME_CREDIT_RECOVERED_LIFETIME <= 100000000000000000000.0000
#   7. -99999.0000 < TOTAL_DUE_AMOUNT_LAST_30D <= 2213.5000
#
# 📊 Leaf Population:
#   • Total samples: 259 (1.79% of cluster)
#   • Train: 227 (1.61% of cluster train)
#   • val: 32 (9.58% of cluster val)
#   • val purity: 12.36% (cluster baseline: 2.31%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.2907 (29.07%)
#   • val Class 1 rate: 0.4062 (40.62%)
#   • Absolute difference: 0.1155
#   • Relative change: 39.73%
#   • ✓ Class 1 INCREASED by 39.73%
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 4, Leaf #4 | Impact Score: 154.19
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (8 conditions):
#   1. -698751.7000 < MIN_AVAILABLE_BALANCE_60TO90D_SMS_BANKING <= 477.9950
#   2. 0.0000 < NUM_MAINBILLSCLICK_121_TO_150_D <= 0.5000
#   3. 0.0000 < NUM_MAINMONEYCLICK_151_TO_180_D <= 0.5000
#   4. 0.0000 < NUM_MAINMONEYCLICK_31_TO_60_D <= 0.5000
#   5. 0.0000 < NUM_MAINMONEYCLICK_61_TO_90_D <= 0.5000
#   6. 0.0000 < NUM_PAYOUTSETTLED_1_TO_30_D <= 0.5000
#   7. -99999.0000 < RATIO_AVG_DEBIT_AMOUNT_AVG_CDT_AMT_LAST30D_SMS_BANKING <= 0.9121
#   8. -99999.0000 < TOTAL_DUE_AMOUNT_LAST_30D <= 2213.5000
#
# 📊 Leaf Population:
#   • Total samples: 2,051 (14.18% of cluster)
#   • Train: 2,003 (14.18% of cluster train)
#   • val: 48 (14.37% of cluster val)
#   • val purity: 2.34% (cluster baseline: 2.31%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.3415 (34.15%)
#   • val Class 1 rate: 0.4167 (41.67%)
#   • Absolute difference: 0.0752
#   • Relative change: 22.02%
#   • ✓ Class 1 INCREASED by 22.02%
#
# ========================================================================================================================
#
#
# ########################################################################################################################
# ########################################################################################################################
# ANALYZING CLUSTER 5
# ########################################################################################################################
# ########################################################################################################################
#
# ✓ Cluster 5 samples: Train=9,678, val=130
#
# ✓ Decision tree fitted for Cluster 5
#   - Tree depth: 7
#   - Number of leaves: 17
#   - Min samples per leaf: 98
#
# 📊 Top 10 features distinguishing val from train in Cluster 5:
#                                                                feature  importance
#                               MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE    0.196198
#                                                            BUREAUSCORE    0.189158
#                                          NUM_MAINMONEYCLICK_61_TO_90_D    0.173226
#                                           NUM_PAYOUTCREATED_31_TO_60_D    0.158862
#                                           TOTAL_OVERDUE_AMOUNT_60TO90D    0.153553
# RATIO_TOTAL_CREDIT_AMOUNT_BANK_TRANSFER_LAST30D_VS_30TO60D_SMS_BANKING    0.054390
#                       MAX_DAYS_SINCE_LAST_PAYMENT_ACTIVE_AND_UNSECURED    0.040039
#                  RATIO_CREDIT_GIVEN_LIFETIME_CREDIT_RECOVERED_LIFETIME    0.024538
#                             MAX_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT    0.005160
#                   RATIO_CREDIT_TAKEN_LIFETIME_CREDIT_PAIDBACK_LIFETIME    0.003893
#
# ========================================================================================================================
# LEAF CHARACTERISTICS FOR CLUSTER 5
# ========================================================================================================================
# ✓ Valid leaf paths: 2
#
# TOP 5 LEAVES WITH HIGHEST CLASS 1 SUPPRESSION:
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 5, Leaf #1 | Impact Score: 3.86
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (6 conditions):
#   1. 640.0000 < BUREAUSCORE <= 776.5000
#   2. -26384.0000 < MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE <= 6990.5000
#   3. 0.0000 < NUM_MAINMONEYCLICK_61_TO_90_D <= 0.5000
#   4. 0.0000 < NUM_PAYOUTCREATED_31_TO_60_D <= 0.5000
#   5. 1.0975 < RATIO_TOTAL_CREDIT_AMOUNT_BANK_TRANSFER_LAST30D_VS_30TO60D_SMS_BANKING <= 12360.1910
#   6. -99999.0000 < TOTAL_OVERDUE_AMOUNT_60TO90D <= 226.5000
#
# 📊 Leaf Population:
#   • Total samples: 99 (1.01% of cluster)
#   • Train: 77 (0.80% of cluster train)
#   • val: 22 (16.92% of cluster val)
#   • val purity: 22.22% (cluster baseline: 1.33%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.3247 (32.47%)
#   • val Class 1 rate: 0.3636 (36.36%)
#   • Absolute difference: 0.0390
#   • Relative change: 12.00%
#   • ✓ Class 1 INCREASED by 12.00%
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 5, Leaf #2 | Impact Score: 13.50
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (5 conditions):
#   1. -99999.0000 < BUREAUSCORE <= 776.5000
#   2. 6990.5000 < MIN_CURRENT_BALANCE_UNSECURED_AND_ACTIVE <= 332416.0000
#   3. 0.0000 < NUM_MAINMONEYCLICK_61_TO_90_D <= 0.5000
#   4. 0.0000 < NUM_PAYOUTCREATED_31_TO_60_D <= 0.5000
#   5. -99999.0000 < TOTAL_OVERDUE_AMOUNT_60TO90D <= 226.5000
#
# 📊 Leaf Population:
#   • Total samples: 177 (1.80% of cluster)
#   • Train: 118 (1.22% of cluster train)
#   • val: 59 (45.38% of cluster val)
#   • val purity: 33.33% (cluster baseline: 1.33%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.2797 (27.97%)
#   • val Class 1 rate: 0.3559 (35.59%)
#   • Absolute difference: 0.0763
#   • Relative change: 27.27%
#   • ✓ Class 1 INCREASED by 27.27%
#
# ========================================================================================================================
#
#
# ########################################################################################################################
# ########################################################################################################################
# ANALYZING CLUSTER 6
# ########################################################################################################################
# ########################################################################################################################
#
# ⚠️  Skipping Cluster 6: Insufficient samples
#    Train: 2, val: 0
#
# ########################################################################################################################
# ########################################################################################################################
# ANALYZING CLUSTER 7
# ########################################################################################################################
# ########################################################################################################################
#
# ✓ Cluster 7 samples: Train=818, val=63
#
# ✓ Decision tree fitted for Cluster 7
#   - Tree depth: 4
#   - Number of leaves: 10
#   - Min samples per leaf: 50
#
# 📊 Top 10 features distinguishing val from train in Cluster 7:
#                                                                 feature  importance
#                                                             BUREAUSCORE    0.457823
#                               NUM_AVAILABLE_BALANCE_LAST30D_SMS_BANKING    0.189592
#                                          NUM_MAINMONEYCLICK_91_TO_120_D    0.164388
# RATIO_NUM_DEBIT_TXNS_GREATERTHAN_10000_LAST30D_VS_120TO150D_SMS_BANKING    0.088553
#                               MAX_DAYS_PAST_DUE_UNSECURED_60_TO_90_DAYS    0.080104
#                    AVG_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT_UNSECURED    0.014854
#              RATIO_AVG_AVAILABLE_BALANCE_LAST30D_VS_30TO60D_SMS_BANKING    0.004685
#                                       MAX_DAYS_PAST_DUE_210_TO_240_DAYS    0.000000
#                         NUM_DEBIT_TXNS_LESSTHAN_100_60TO90D_SMS_BANKING    0.000000
#                      RATIO_CREDIT_TAKEN_LAST30D_CREDIT_PAIDBACK_LAST30D    0.000000
#
# ========================================================================================================================
# LEAF CHARACTERISTICS FOR CLUSTER 7
# ========================================================================================================================
# ✓ Valid leaf paths: 1
#
# TOP 5 LEAVES WITH HIGHEST CLASS 1 SUPPRESSION:
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 7, Leaf #1 | Impact Score: 0.31
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (3 conditions):
#   1. -99999.0000 < BUREAUSCORE <= 729.5000
#   2. -99999.0000 < NUM_AVAILABLE_BALANCE_LAST30D_SMS_BANKING <= 29.5000
#   3. -99999.0000 < NUM_MAINMONEYCLICK_91_TO_120_D <= 0.5000
#
# 📊 Leaf Population:
#   • Total samples: 70 (7.95% of cluster)
#   • Train: 45 (5.50% of cluster train)
#   • val: 25 (39.68% of cluster val)
#   • val purity: 35.71% (cluster baseline: 7.15%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.3556 (35.56%)
#   • val Class 1 rate: 0.3600 (36.00%)
#   • Absolute difference: 0.0044
#   • Relative change: 1.25%
#   • ✓ Class 1 INCREASED by 1.25%
#
# ========================================================================================================================
#
#
# ########################################################################################################################
# ########################################################################################################################
# ANALYZING CLUSTER 8
# ########################################################################################################################
# ########################################################################################################################
#
# ✓ Cluster 8 samples: Train=13,939, val=787
#
# ✓ Decision tree fitted for Cluster 8
#   - Tree depth: 8
#   - Number of leaves: 49
#   - Min samples per leaf: 147
#
# 📊 Top 10 features distinguishing val from train in Cluster 8:
#                                              feature  importance
#                                          BUREAUSCORE    0.390949
#                        NUM_MAINMONEYCLICK_61_TO_90_D    0.184484
#                        NUM_MAINMONEYCLICK_31_TO_60_D    0.096781
#                                  AVG_CURRENT_BALANCE    0.059602
#                                  AVG_AMOUNT_PAST_DUE    0.046027
#                      NUM_MAINBILLSCLICK_151_TO_180_D    0.034883
#           MIN_HIGHEST_CREDIT_OR_ORIGINAL_LOAN_AMOUNT    0.029058
#                        TIMES_DPD_GT_30_LAST_510_DAYS    0.024606
#             AVG_AMOUNT_PAST_DUE_UNSECURED_AND_ACTIVE    0.018409
# RATIO_CREDIT_TAKEN_LIFETIME_CREDIT_PAIDBACK_LIFETIME    0.015898
#
# ========================================================================================================================
# LEAF CHARACTERISTICS FOR CLUSTER 8
# ========================================================================================================================
# ✓ Valid leaf paths: 13
#
# TOP 5 LEAVES WITH HIGHEST CLASS 1 SUPPRESSION:
#
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 8, Leaf #1 | Impact Score: -25.36
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (6 conditions):
#   1. 1.0278 < AVG_CURRENT_BALANCE <= 3059139.0000
#   2. 761.5000 < BUREAUSCORE <= 787.5000
#   3. 0.0000 < NUM_MAINMONEYCLICK_31_TO_60_D <= 0.5000
#   4. 0.5297 < RATIO_AVG_DEBIT_AMOUNT_AVG_CDT_AMT_60TO90D_SMS_BANKING <= 60.5329
#   5. 1.0965 < RATIO_CREDIT_GIVEN_LIFETIME_CREDIT_RECOVERED_LIFETIME <= 15000.4944
#   6. 0.0000 < TIMES_DPD_GT_30_LAST_720_DAYS <= 0.5000
#
# 📊 Leaf Population:
#   • Total samples: 244 (1.66% of cluster)
#   • Train: 204 (1.46% of cluster train)
#   • val: 40 (5.08% of cluster val)
#   • val purity: 16.39% (cluster baseline: 5.34%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.3039 (30.39%)
#   • val Class 1 rate: 0.2000 (20.00%)
#   • Absolute difference: -0.1039
#   • Relative change: -34.19%
#   • ⚠️  Class 1 DECREASED by 34.19%
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 8, Leaf #2 | Impact Score: -19.82
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (6 conditions):
#   1. -99999.0000 < AVG_AMOUNT_PAST_DUE <= 39.7750
#   2. 485.0000 < BUREAUSCORE <= 716.5000
#   3. 0.0000 < NUM_MAINBILLSCLICK_151_TO_180_D <= 0.5000
#   4. 0.0000 < NUM_MAINMONEYCLICK_31_TO_60_D <= 0.5000
#   5. 0.0000 < NUM_MAINMONEYCLICK_61_TO_90_D <= 0.5000
#   6. 0.5000 < TIMES_DPD_GT_30_LAST_510_DAYS <= 23.0000
#
# 📊 Leaf Population:
#   • Total samples: 153 (1.04% of cluster)
#   • Train: 118 (0.85% of cluster train)
#   • val: 35 (4.45% of cluster val)
#   • val purity: 22.88% (cluster baseline: 5.34%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.4153 (41.53%)
#   • val Class 1 rate: 0.2857 (28.57%)
#   • Absolute difference: -0.1295
#   • Relative change: -31.20%
#   • ⚠️  Class 1 DECREASED by 31.20%
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 8, Leaf #3 | Impact Score: -14.56
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (6 conditions):
#   1. -1.4000 < AVG_CURRENT_BALANCE <= 1.0278
#   2. 761.5000 < BUREAUSCORE <= 800.5000
#   3. 0.0000 < NUM_MAINMONEYCLICK_31_TO_60_D <= 0.5000
#   4. 0.0000 < NUM_MAINMONEYCLICK_61_TO_90_D <= 0.5000
#   5. -99999.0000 < RATIO_AVG_DEBIT_AMOUNT_AVG_CDT_AMT_90TO120D_SMS_BANKING <= 0.5571
#   6. 1.0776 < RATIO_CREDIT_TAKEN_LIFETIME_CREDIT_PAIDBACK_LIFETIME <= 3852.9827
#
# 📊 Leaf Population:
#   • Total samples: 147 (1.00% of cluster)
#   • Train: 122 (0.88% of cluster train)
#   • val: 25 (3.18% of cluster val)
#   • val purity: 17.01% (cluster baseline: 5.34%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.4590 (45.90%)
#   • val Class 1 rate: 0.3600 (36.00%)
#   • Absolute difference: -0.0990
#   • Relative change: -21.57%
#   • ⚠️  Class 1 DECREASED by 21.57%
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 8, Leaf #4 | Impact Score: -10.91
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (5 conditions):
#   1. -99999.0000 < AVG_AMOUNT_PAST_DUE <= 39.7750
#   2. 3.0000 < BUREAUSCORE <= 761.5000
#   3. 0.5000 < NUM_MAINBILLSCLICK_151_TO_180_D <= 45.0000
#   4. 0.0000 < NUM_MAINMONEYCLICK_31_TO_60_D <= 0.5000
#   5. 0.0000 < NUM_MAINMONEYCLICK_61_TO_90_D <= 0.5000
#
# 📊 Leaf Population:
#   • Total samples: 278 (1.89% of cluster)
#   • Train: 189 (1.36% of cluster train)
#   • val: 89 (11.31% of cluster val)
#   • val purity: 32.01% (cluster baseline: 5.34%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.3651 (36.51%)
#   • val Class 1 rate: 0.3258 (32.58%)
#   • Absolute difference: -0.0392
#   • Relative change: -10.75%
#   • ⚠️  Class 1 DECREASED by 10.75%
#
# ------------------------------------------------------------------------------------------------------------------------
# Cluster 8, Leaf #5 | Impact Score: -10.29
# ------------------------------------------------------------------------------------------------------------------------
#
# 📍 Decision Path (6 conditions):
#   1. -400160.0000 < AVG_CURRENT_BALANCE <= 1.0278
#   2. 761.5000 < BUREAUSCORE <= 800.5000
#   3. 0.0000 < NUM_MAINMONEYCLICK_31_TO_60_D <= 0.5000
#   4. 0.0000 < NUM_MAINMONEYCLICK_61_TO_90_D <= 0.5000
#   5. 0.5571 < RATIO_AVG_DEBIT_AMOUNT_AVG_CDT_AMT_90TO120D_SMS_BANKING <= 862.4267
#   6. 1.0776 < RATIO_CREDIT_TAKEN_LIFETIME_CREDIT_PAIDBACK_LIFETIME <= 24735.0000
#
# 📊 Leaf Population:
#   • Total samples: 152 (1.03% of cluster)
#   • Train: 111 (0.80% of cluster train)
#   • val: 41 (5.21% of cluster val)
#   • val purity: 26.97% (cluster baseline: 5.34%)
#
# 🎯 Leaf Class 1 Analysis:
#   • Train Class 1 rate: 0.3604 (36.04%)
#   • val Class 1 rate: 0.2927 (29.27%)
#   • Absolute difference: -0.0677
#   • Relative change: -18.78%
#   • ⚠️  Class 1 DECREASED by 18.78%
#
# ========================================================================================================================
#
#
# ########################################################################################################################
# ########################################################################################################################
# ANALYZING CLUSTER 9
# ########################################################################################################################
# ########################################################################################################################
#
# ⚠️  Skipping Cluster 9: Insufficient samples
#    Train: 1, val: 0
#
# ########################################################################################################################
# ✓ Cluster-wise degradation analysis complete
# ########################################################################################################################

# %% [markdown]
# ## Step 4: Comprehensive Summary and Export

# %%
# Create comprehensive summary
print(f"{'='*120}")
print("COMPREHENSIVE DEGRADATION ANALYSIS SUMMARY")
print(f"{'='*120}\n")

# Overall statistics
print(f"📊 OVERALL STATISTICS:")
print(f"  • Total train samples: {len(X_train):,}")
print(f"  • Total val samples: {len(X_val):,}")
print(f"  • Overall train Class 1 rate: {y_train.mean():.4f} ({y_train.mean()*100:.2f}%)")
print(f"  • Overall val Class 1 rate: {y_val.mean():.4f} ({y_val.mean()*100:.2f}%)")
print(f"  • Overall Class 1 degradation: {((y_val.mean() - y_train.mean()) / y_train.mean() * 100):.2f}%")

# Clustering summary with Optuna results
print(f"\n🔍 CLUSTERING SUMMARY (OPTUNA-OPTIMIZED):")
print(f"  • Optimization trials run: 100")
print(f"  • Optimal number of clusters: {optimal_n_clusters}")
print(f"  • Optimal number of features: {optimal_n_features}")
print(f"  • Best initialization method: {optimal_init}")
print(f"  • Optimal n_init: {optimal_n_init}")
print(f"  • Optimal max_iter: {optimal_max_iter}")
print(f"  • Best silhouette score: {best_silhouette_score:.4f}")
print(f"  • Silhouette quality: {'Excellent' if best_silhouette_score > 0.7 else 'Good' if best_silhouette_score > 0.5 else 'Moderate' if best_silhouette_score > 0.3 else 'Weak'}")

# Cluster-wise summary
print(f"\n📋 CLUSTER-WISE BREAKDOWN:")
print(cluster_stats_df.to_string(index=False))

# Identify clusters with highest degradation
worst_clusters = cluster_stats_df.nsmallest(3, 'class1_diff')
print(f"\n⚠️  TOP 3 CLUSTERS WITH HIGHEST CLASS 1 DEGRADATION:")
for idx, row in worst_clusters.iterrows():
    print(f"  {idx+1}. Cluster {row['cluster_id']}: {row['class1_diff']:.4f} ({row['class1_diff_pct']:.2f}%)")
    print(f"     - Train samples: {row['n_train']:,}, val samples: {row['n_val']:,}")

# Export results
print(f"\n{'='*120}")
print("EXPORTING RESULTS")
print(f"{'='*120}")

# Export cluster statistics
cluster_stats_file = '401_clusterwise_cluster_stats.csv'
# cluster_stats_df.to_csv(cluster_stats_file, index=False)
print(f"✓ Cluster statistics exported to: {cluster_stats_file}")

# Export Optuna optimization results
optuna_results_file = '401_optuna_optimization_results.csv'
trials_df = study.trials_dataframe()
# trials_df.to_csv(optuna_results_file, index=False)
print(f"✓ Optuna optimization results exported to: {optuna_results_file}")

# Combine and export all leaf results
if all_cluster_results:
    all_leaves_df = pd.concat(all_cluster_results, axis=0, ignore_index=True)
    all_leaves_df['path_rank_within_cluster'] = all_leaves_df.groupby('cluster_id').cumcount() + 1
    
    leaves_file = '401_clusterwise_leaf_analysis.csv'
    # all_leaves_df.to_csv(leaves_file, index=False)
    print(f"✓ Leaf analysis exported to: {leaves_file}")
    
    # Summary of leaf-level degradation
    print(f"\n📈 LEAF-LEVEL SUMMARY:")
    print(f"  • Total valid leaves across all clusters: {len(all_leaves_df):,}")
    print(f"  • Leaves with Class 1 degradation: {(all_leaves_df['class1_diff'] < 0).sum():,}")
    print(f"  • Leaves with Class 1 improvement: {(all_leaves_df['class1_diff'] > 0).sum():,}")
    print(f"  • Average impact score: {all_leaves_df['impact_score'].mean():.2f}")
    print(f"  • Most negative impact: {all_leaves_df['impact_score'].min():.2f}")
else:
    print(f"⚠️  No leaf results to export")

print(f"\n{'='*120}")
print("KEY INSIGHTS AND RECOMMENDATIONS")
print(f"{'='*120}")
print(f"\n✓ OPTUNA OPTIMIZATION INSIGHTS:")
print(f"  • valed 100 different hyperparameter combinations")
print(f"  • Found optimal configuration with {best_silhouette_score:.4f} silhouette score")
print(f"  • Key findings from hyperparameter importance:")
importance = optuna.importance.get_param_importances(study)
sorted_importance = sorted(importance.items(), key=lambda x: x[1], reverse=True)
for param, imp_val in sorted_importance[:3]:
    print(f"    - {param} (importance: {imp_val:.4f})")

print(f"\n✓ CLUSTERING INSIGHTS:")
print(f"  • Data naturally segments into {optimal_n_clusters} distinct clusters")
print(f"  • Silhouette score of {best_silhouette_score:.4f} indicates {'excellent' if best_silhouette_score > 0.7 else 'good' if best_silhouette_score > 0.5 else 'moderate' if best_silhouette_score > 0.3 else 'weak'} cluster separation")
print(f"  • Used {optimal_n_features} most important features for clustering")

print(f"\n✓ DEGRADATION PATTERNS:")
if len(cluster_stats_df[cluster_stats_df['class1_diff'] < 0]) > 0:
    print(f"  • {len(cluster_stats_df[cluster_stats_df['class1_diff'] < 0])} out of {optimal_n_clusters} clusters show Class 1 degradation")
    print(f"  • Degradation is {'concentrated' if len(cluster_stats_df[cluster_stats_df['class1_diff'] < 0]) <= optimal_n_clusters/2 else 'widespread'} across clusters")
else:
    print(f"  • No clusters show Class 1 degradation")

print(f"\n💡 ACTIONABLE RECOMMENDATIONS:")
print(f"  1. Focus on clusters with highest degradation (see top 3 above)")
print(f"  2. Review leaf characteristics within each problem cluster")
print(f"  3. Investigate feature distributions in high-impact leaves")
print(f"  4. Consider cluster-specific model retraining or recalibration")
print(f"  5. Validate if degradation patterns align with operational changes")
print(f"  6. The Optuna-optimized clustering provides more robust segmentation than manual parameter selection")

print(f"\n{'='*120}")
print("✓ ANALYSIS COMPLETE")
print(f"{'='*120}")
# Out:
# ========================================================================================================================
# COMPREHENSIVE DEGRADATION ANALYSIS SUMMARY
# ========================================================================================================================
#
# 📊 OVERALL STATISTICS:
#   • Total train samples: 123,208
#   • Total val samples: 7,802
#   • Overall train Class 1 rate: 0.3119 (31.19%)
#   • Overall val Class 1 rate: 0.3013 (30.13%)
#   • Overall Class 1 degradation: -3.37%
#
# 🔍 CLUSTERING SUMMARY (OPTUNA-OPTIMIZED):
#   • Optimization trials run: 100
#   • Optimal number of clusters: 10
#   • Optimal number of features: 11
#   • Best initialization method: k-means++
#   • Optimal n_init: 6
#   • Optimal max_iter: 142
#   • Best silhouette score: 0.7128
#   • Silhouette quality: Excellent
#
# 📋 CLUSTER-WISE BREAKDOWN:
#  cluster_id  n_train  n_val  train_class1_rate  val_class1_rate  class1_diff  class1_diff_pct
#           0    17647   2412           0.314614         0.296434    -0.018180        -5.778467
#           1     9571    486           0.384704         0.333333    -0.051370       -13.353250
#           2    37461   1274           0.304183         0.328885     0.024702         8.120895
#           3    19962   2316           0.290903         0.267271    -0.023632        -8.123526
#           4    14129    334           0.281549         0.332335     0.050787        18.038358
#           5     9678    130           0.297892         0.323077     0.025185         8.454334
#           6        2      0           0.500000         0.000000    -0.500000      -100.000000
#           7      818     63           0.315403         0.285714    -0.029689        -9.413068
#           8    13939    787           0.349164         0.336722    -0.012442        -3.563506
#           9        1      0           0.000000         0.000000     0.000000         0.000000
#
# ⚠️  TOP 3 CLUSTERS WITH HIGHEST CLASS 1 DEGRADATION:
#   7. Cluster 6.0: -0.5000 (-100.00%)
#      - Train samples: 2.0, val samples: 0.0
#   2. Cluster 1.0: -0.0514 (-13.35%)
#      - Train samples: 9,571.0, val samples: 486.0
#   8. Cluster 7.0: -0.0297 (-9.41%)
#      - Train samples: 818.0, val samples: 63.0
#
# ========================================================================================================================
# EXPORTING RESULTS
# ========================================================================================================================
# ✓ Cluster statistics exported to: 401_clusterwise_cluster_stats.csv
# ✓ Optuna optimization results exported to: 401_optuna_optimization_results.csv
# ✓ Leaf analysis exported to: 401_clusterwise_leaf_analysis.csv
#
# 📈 LEAF-LEVEL SUMMARY:
#   • Total valid leaves across all clusters: 90
#   • Leaves with Class 1 degradation: 51
#   • Leaves with Class 1 improvement: 39
#   • Average impact score: -5.88
#   • Most negative impact: -113.96
#
# ========================================================================================================================
# KEY INSIGHTS AND RECOMMENDATIONS
# ========================================================================================================================
#
# ✓ OPTUNA OPTIMIZATION INSIGHTS:
#   • valed 100 different hyperparameter combinations
#   • Found optimal configuration with 0.7128 silhouette score
#   • Key findings from hyperparameter importance:
#     - n_features (importance: 0.9747)
#     - n_clusters (importance: 0.0112)
#     - max_iter (importance: 0.0111)
#
# ✓ CLUSTERING INSIGHTS:
#   • Data naturally segments into 10 distinct clusters
#   • Silhouette score of 0.7128 indicates excellent cluster separation
#   • Used 11 most important features for clustering
#
# ✓ DEGRADATION PATTERNS:
#   • 6 out of 10 clusters show Class 1 degradation
#   • Degradation is widespread across clusters
#
# 💡 ACTIONABLE RECOMMENDATIONS:
#   1. Focus on clusters with highest degradation (see top 3 above)
#   2. Review leaf characteristics within each problem cluster
#   3. Investigate feature distributions in high-impact leaves
#   4. Consider cluster-specific model retraining or recalibration
#   5. Validate if degradation patterns align with operational changes
#   6. The Optuna-optimized clustering provides more robust segmentation than manual parameter selection
#
# ========================================================================================================================
# ✓ ANALYSIS COMPLETE
# ========================================================================================================================
